# %%
import numpy as np
from scipy.linalg import expm

# fix seed: results of training depend on seed value; typically, one runs several simulations 
# and post-selects the best performance
seed=0 
np.random.seed(seed)

# fix output array
np.set_printoptions(suppress=True,precision=2)

# %% [markdown]
# # Deep Policy Gradient (PG)
#
#
# In this notebook, our goal is to implement the REINFORCE algorithm for policy gradient using [JAX](https://jax.readthedocs.io/en/latest/).
#
# We will apply this RL algorithm to control a single quantum bit of information (qubit) in the presence of different kinds of noise and spontaneous emission.
#
# ## The REINFORCE Algorithm
#
# The reinforcement learning objective $\mathbf J$ is the expected total return $\mathbf G$, following the policy $\pi$. If the transition probability is denoted by $p(s'|s,a)$, and the initial state distribution is $p(s_0)$, the probability for a trajectory $\tau = (s_0,a_0,r_1,s_1,a_1,\dots,s_{T-1},a_{T-1},r_T,s_T)$ to occur can be written as
#
# $$
# P_\pi(\tau) = p(s_0)\prod_{t=1}^T \pi(a_t|s_t)p(s_{t+1}|s_t,a_t).
# $$
#
# The RL objective then takes the form
#
# $$
# \mathbf J = \mathbb{E}_{\tau\sim P_\pi} \left[ \mathbf G(\tau) | s_{t=0}=s_0 \right],\qquad \mathbf G(\tau)=\sum_{t=1}^T r(s_t,a_t).
# $$
#
# Policy gradient methods in RL approximate directly the policy $\pi\approx\pi_\theta$ using a variational ansatz, parametrized by some unknown parameters $\theta$ (e.g., the weights and biases of a neural network). The goal is then to find those optimal parameters $\theta$, which maximize the RL objective $\mathbf J(\theta)$. To define an update rule for $\theta$, we can use gradient ascent. This requires us to evaluate the gradient of the RL objective,
# $$
# \mathbf J(\theta) = \mathbb{E}_{\tau\sim P_{\pi_\theta}} \left[ \mathbf G(\tau) | s_{t=0}=s_0 \right]
#     = \int\mathcal{D}\tau\; P_{\pi_{\theta}}(\tau)\; G(\tau),
# $$
# w.r.t. the parameters $\theta$.
#
# In a model-free setting, we don't have access to the transition probabilities $p(s'|s,a)$ and this requires us to be able to estimate the gradients from samples. This can be accomplished by noticing that $\nabla_\theta P_{\pi_\theta} = P_{\pi_\theta} \nabla_\theta \log P_{\pi_\theta}$ (almost everywhere, i.e. up to a set of measure zero):
#
# $$
# \nabla_\theta \mathbf J(\theta)
# = \nabla_\theta \mathbb{E}_{\tau\sim P_\pi} \left[ \sum_{t=1}^T r(s_t,a_t) | s_{t=0}=s_0 \right]
# = \nabla_\theta \int\mathcal{D}\tau\; P_{\pi_\theta}(\tau)\; \mathbf G(\tau)
# = \int\mathcal{D}\tau\; \nabla_\theta P_{\pi_\theta}(\tau)\; \mathbf G(\tau)
# = \int\mathcal{D}\tau\; P_{\pi_\theta} \nabla_\theta \log P_{\pi_\theta}\; \mathbf G(\tau)
# = \nabla_\theta \mathbb{E}_{\tau\sim P_\pi} \left[ \nabla_\theta \log P_{\pi_\theta}\; \mathbf G \right] .
# $$
# Since the initial state distribution $p(s_0)$ and the transition probabilities $p(s_{t+1}|s_t,a_t)$ are independent of $\theta$, using the definition of $P_{\pi_\theta}$, we see that $\nabla_\theta \log P_{\pi_\theta}(\tau) = \nabla_\theta \log \pi_\theta(\tau)$ where $\pi_\theta(\tau) = \prod_{t=1}^T \pi_\theta(a_t|s_t)$.
#
# We can therefore use Monte Carlo sampling to estimate the gradients directly from a sample of trajectories $\{\tau_j\}_{j=1}^N$ using the policy $\pi_\theta(\tau)$:
# $$
#     \nabla_\theta \mathbf J(\theta) = \mathbb{E}_{\tau\sim P_\pi} \left[\nabla_\theta \log \pi_\theta(\tau)\; \mathbf G(\tau)\right]
#     \approx \frac{1}{N}\sum_{j=1}^N \nabla_\theta \log \pi_\theta(\tau_j)\; \mathbf G(\tau_j)
#     = \frac{1}{N}\sum_{j=1}^N \left( \sum_{t=1}^T \nabla_\theta\; \pi_\theta(a^j_t|s^j_t) \sum_{t'=1}^T r(a^j_{t'},s^j_{t'}) \right),
# $$
# where in the last equality we used $\log \pi_\theta(\tau) = \log \prod_{t=1}^T \pi_\theta(a_t|s_t) = \sum_{t=1}^T \pi_\theta(a^j_t|s^j_t)$, together with the definition of the total return $\mathbf G(\tau)$ above.
#
# To alleviate the problem with the large variance of the gradient estimate, one can introduce a baseline $b=N^{-1}\sum_j \sum_{t'=t}^T r(a^j_{t'}|s^j_{t'})$, defined as the average return over the sample. The policy gradient (PG) update then takes the form
#
# $$
# \nabla_\theta \mathbf J(\theta)
# \approx \frac{1}{N}\sum_{j=1}^N \sum_{t=1}^T \nabla_\theta \log \pi_\theta(a^j_t|s^j_t) \left[\sum_{t'=t}^T r(a^j_{t'}|s^j_{t'})) - b\right].
# $$
#
# One can show that adding this baseline term does not change the expectation value $\nabla_\theta \mathbf J(\theta) = \mathbb{E}_{\tau\sim P_\pi} \left[\nabla_\theta \log \pi_\theta(\tau)\; \mathbf G(\tau)\right]$.
#
# The corresponding gradient *ascent* update rule reads as
#
# $$
# \theta \leftarrow \theta + \alpha \nabla_\theta \mathbf J(\theta),
# $$
# for some step size (or learning rate) $\alpha$.

# %% [markdown]
# ## Qubit Environment: Shortcuts to Adiabaticity
#
# Let us define the qubit environment that models the action of gates on the state of the two-level system (2LS). Our goal is to use RL to improve counter-diabatic (CD) driving. To this end, we first use CD theory to determine the operator to which the CD terms couple. However, instead of using the CD protocol, we let the RL agent find the optimal counter drive.
#
# ### Basic Definitions
#
# The state of a qubit $|\psi\rangle\in\mathbb{C}^2$ is modeled by a two-dimensional complex-valued vector with unit norm: $\langle\psi|\psi\rangle:=\sqrt{|\psi_1|^2+|\psi_2|^2}=1$. Every qubit state is uniquely described by two angles $\theta\in[0,\pi]$ and $\varphi\in[0,2\pi)$:
#
# \begin{eqnarray}
# |\psi\rangle=
# \begin{pmatrix}
# \psi_1 \\ \psi_2
# \end{pmatrix}=
# \mathrm{e}^{i\alpha}
# \begin{pmatrix}
# \cos\frac{\theta}{2} \\
# \mathrm{e}^{i\varphi}\sin\frac{\theta}{2}
# \end{pmatrix}
# \end{eqnarray}
#
# The overall phase $\alpha$ of a single quantum state has no physical meaning.
# Thus, any qubit state can be pictured as an arrow on the unit sphere (called the Bloch sphere) with spherical coordinates $(\theta,\varphi)$.
#
# To operate on qubits, we use quantum gates. Quantum gates are represented as unitary transformations $U\in \mathrm{U(2)}$, where $\mathrm{U(2)}$ is the unitary group. Gates act on qubit states by matrix multiplication to transform an input state $|\psi\rangle$ to the output state $|\psi'\rangle$: $|\psi'\rangle=U|\psi\rangle.$
#
# In quantum platforms, unitary gates are generated by Hamiltonian time evolution. Given an arbitrary time-dependent Hamiltonian $H(t)$, the associated time-evolution operator is given by
# \begin{equation}
#     U(t,0) = \mathcal{T}_t\exp\left(-i \int_0^t\mathrm d t' H(t')\right),
# \end{equation}
# where $\mathcal{t}_t\exp$ denotes the time-ordered exponential, and $t$ is the total time the Hamiltonian is applied for.
#
# For this problem, we consider a two-level system given by the Hamiltonian
# \begin{equation}
# H(t) = \Delta\sigma^x + \nu(t)\sigma^z,
# \end{equation}
# where $\Delta$ sets the energy splitting, and the control field $\nu(t)$ couples the two levels. The identity and the Pauli matrices are defined as
#
# \begin{equation}
# \boldsymbol{1}=\begin{pmatrix}
# 1 & 0 \\ 0 & 1
# \end{pmatrix}
# ,\qquad
# \sigma^x=\begin{pmatrix}
# 0 & 1 \\ 1 & 0
# \end{pmatrix}
# ,\qquad
# \sigma^y=\begin{pmatrix}
# 0 & -i \\ i & 0
# \end{pmatrix}
# ,\ \qquad
# \sigma^z=\begin{pmatrix}
# 1 & 0 \\ 0 & -1
# \end{pmatrix}.
# \end{equation}
#
#
# ### Control Problem
#
# Counter-diabatic driving introduces additional control terms to suppress excitations during the protocol:
# \begin{equation}
# H_\text{CD}(t) = \Delta\sigma^x + \nu(t)\sigma^z - \frac{1}{2}\frac{\Delta\; \dot\nu(t)}{\Delta^2 + \nu^2(t)}\sigma^y.
# \end{equation}
# When evolved using $H_\text{CD}(t)$, the system follows the instantaneous eigenstates of the Hamiltonian $H(t)$ at all times.
#
#
# We now initialize the system in the ground state of the Hamiltonian $H(0)$ at $\nu_i=+2\Delta$, and want to transfer the population in the ground state at $H(t)$ at $\nu_\ast=-2\Delta$ in a finite amount of time $T$ (referred to as the duration of the protocol). The system is subject to the Hamitlnoan
# \begin{equation}
#     H_g(t) = \Delta\sigma^x + \nu(t)\sigma^z - g(t)\sigma^y,
# \end{equation}
# where $\nu(t) = (\nu_\ast-\nu_i)t/T + \nu_i$ is the linear drift term that is always on (and the RL agent has no control over), while $g(t)$ is the unknown counter protocol that we want our RL agent to find.
#
# To determine if a qubit, described by the state $|\psi\rangle$, is in a desired target state $|\psi_\mathrm{target}\rangle$, we compute the fidelity
#
# \begin{eqnarray}
# \mathcal F=|\langle\psi_\mathrm{target}|\psi\rangle|^2 = |(\psi_\mathrm{target})^\ast_1 \psi_1 + (\psi_\mathrm{target})^\ast_2 \psi_2|^2,\qquad \mathcal F\in[0,1]
# \end{eqnarray}
#
# where $\ast$ stands for complex conjugation. Physically, the fidelity corresponds to the angle between the arrows representing the qubit state on the Bloch sphere (we want to maximize the fidelity but minimize the angle between the states).

# %% [markdown]
# ### Constructing the Qubit Environment
#
# Now, let us define an episodic RL environment, which contains the laws of physics that govern the dynamics of the qubit (i.e. the application of the gate operations corresponding to the Hamiltonian evolution to the qubit state). Our RL agent will later interact with this environment to learn how to control the qubit to bring it from an initial state to a prescribed target state (see above).
#
# We define the RL states $s=(\theta,\varphi)$ as an array containing the Bloch sphere angles of the quantum state. For each timestep of size $\delta t$ within an episode, the agent has to determine the value of the protocol function $g(t)$; to this end, starting from some initial value $g_i$, we let the agent find the optimal relative change in the protocol (i.e., by now much the protocol value has to jump at the given timestep). In practice, we define a minimum protocol size $\delta g$, and consider $2n+1$ steps of size $(-n\delta g, -(n-1)\delta g, \dots, -\delta g, 0,\delta g,\dots, (n-1)\delta g, n\delta g)$ that the agent has to choose from.
#
# We use the logarithmic fidelity w.r.t. the target state at the end of the protocol
# \begin{equation}
#     r_t=-\log_{10}\left(1-\mathcal F\right),\qquad \mathcal F=|\langle\psi_\ast|\psi(T)\rangle|^2,\qquad |\psi(T)\rangle = U(T,0)|\psi_i\rangle,
# \end{equation}
# as a reward. The logarithm allows us to learn on a logarithmic scale. Note also that the reward is sparse (i.e., given only at the end of the episode) -- this reflects the character of quantum measurements that collapse the wavefunction.
#
# **state space:** $\mathbf{S} = \{(\theta,\varphi)|\theta\in[0,\pi],\varphi\in[0,2\pi)\}$. There are no well-defined terminal states in this task. Instead, we consider a fixed number of time steps, after which the episode terminates deterministically.
#
# **action space:** $\mathbf{A} = \{-n,-(n-1),\cdots,-1,0,1,\cdots,n-1,n\}$. Actions act on RL states as follows:
# 1. if the current state is $s=(\theta,\varphi)$, we first create the quantum state $|\psi(s)\rangle$;
# 2. we apply the gate $U_a$ corresponding to action $a$ to the quantum state, defined by:
# \begin{equation}
#     U_a = \exp(-i \delta t H_{a\times\delta g}(n\delta t)),\qquad H_{a\times\delta g}(n\delta t) = \Delta\sigma^x + \nu(n\delta t)\sigma^z - a\times\delta g\sigma^y,
# \end{equation}
# where $n$ labels the time steps (such the current time is $t=n\delta t$), $a\in\mathbf{A}$, and $\delta g$ is the minimum protocol size.
# 4. we obtain the new quantum state $|\psi(s')\rangle = U_a|\psi(s)\rangle$.
# 5. last, we compute the Bloch sphere coordinates which define the next state $s'=(\theta',\varphi')$, using the Bloch sphere parametrization for qubits given above.
# Note that all actions are allowed from every state.
#
#
# **reward space:** $\mathbf{R}=[0,+\infty)$. The reward is zero at each step during the protocol: $r_{t<T}=0$, except at the last step, where we use the fidelity between the final state $s_T$ and the target state $s_\ast$ as a reward at the end of every protocol:
#
# $$r(s,s',a)= r_T = -\log_{10}\left(1-\mathcal F\right),\qquad \mathcal F=|\langle\psi_\ast|\psi(T)\rangle|^2$$
#
# for all states $s,s'\in\mathbf{S}$ and actions $a\in\mathbf{A}$.

# %%
class QubitEnv():
    """
    Gym style environment for RL. You may also inherit the class structure from OpenAI Gym. 
    Parameters:
        n_time_steps:   int
                        Total number of time steps within each episode
        seed:   int
                seed of the RNG (for reproducibility)
    """
    
    def __init__(self, n_time_steps, seed):
        """
        Initialize the environment.
        
        """
        
        self.n_time_steps = n_time_steps
        
        ### define action space variables
        max_action = 10
        self.n_actions = 2*max_action+1 # action space size
        self.action_space=np.linspace(-max_action,+max_action, self.n_actions, dtype=int) 
        self.actions = np.arange(self.n_actions)


        # set model parameters
        self.T = 1.2 # total duration of protocol
        self.dt = self.T/self.n_time_steps # time step
        
        self.Delta=1.0 # splitting
        self.h_init  =+2.0 # initial field value
        self.h_target=-2.0 # target field value
        self.delta_h = (self.h_target-self.h_init)/(max_action*self.n_time_steps)

        # linear ramp
        self.h_t = lambda t: (self.h_target-self.h_init)*t/self.T + self.h_init
        self.h_t_prime = lambda t: (self.h_target-self.h_init)/self.T
        # self.h_t = lambda t: self.h_target*2.0*(-0.5 + np.sin(0.5*np.pi*t/self.T)**2 )
        # self.h_t_prime = lambda t: self.h_target*2.0 * 2.0*(0.5*np.pi/self.T)*np.sin(0.5*np.pi*t/self.T)*np.cos(0.5*np.pi*t/self.T)
        
        # define Pauli matrices
        self.Id     =np.array([[1.0,0.0  ], [0.0 ,+1.0]])
        self.sigma_x=np.array([[0.0,1.0  ], [1.0 , 0.0]])
        self.sigma_y=np.array([[0.0,-1.0j], [1.0j, 0.0]])
        self.sigma_z=np.array([[1.0,0.0  ], [0.0 ,-1.0]])
        
        
        ### define state space variables
        H = lambda h: self.Delta*self.sigma_x + h*self.sigma_z
        # initial states
        E_init,V_init = np.linalg.eigh(H(self.h_init))
        self.psi_init = V_init[:,0]
        # target state
        E_target,V_target = np.linalg.eigh(H(self.h_target))
        self.psi_target = V_target[:,0]
        
        # compute Bloch sphere coordinates
        self.S_target = self.qubit_to_RL_state(self.psi_target)
        
        
        # set seed
        self.set_seed(seed)
        self.reset()
    
    def compute_gate(self, action,):
        """
        Given the action, computes the gate to be applied on the qubit.
        Parameters:
            action: int
                    the index of the respective action in the action array.
        Returns:
            output: np.ndarray
                    unitary matrix encoding the gate operation. 
        """
        
        # drift part of Hamiltonian, always on, ~ sigma_x
        drive = self.h_t(self.dt*self.ep_step) 
        # control part of the Hamiltonian, controlled by RL agent, ~ sigma_y
        self.CD_drive += self.delta_h*self.action_space[action] 
        
        # total angle of rotation = dt x norm of the total external field
        norm = self.dt * np.sqrt(self.Delta**2 + drive**2 + self.CD_drive**2)

        # \exp(-i norm * \vec{n} \dot \vec{\sigma})
        gate = np.cos(norm)*self.Id - 1j*np.sin(norm)*self.dt/norm*(self.Delta * self.sigma_x + 
                                                                    drive * self.sigma_z - 
                                                                    self.CD_drive * self.sigma_y
                                                               )
        return gate
    
    def step(self, action):
        """
        Interface between environment and agent. Performs one step in the environemnt.
        Parameters:
            action: int
                    the index of the respective action in the action array
        Returns:
            output: (object, float, bool)
                    information provided by the environment about its current state:
                    (state, reward, done)
        """

        # apply gate to quantum state
        gate = self.compute_gate(action)
        
        # apply unitary
        self.psi = gate.dot(self.psi)
        
        # compute RL state
        self.state = self.qubit_to_RL_state(self.psi)
        
        self.ep_step+=1 # increment step

        # compute reward
        if self.ep_step == self.n_time_steps:
            #reward = np.abs( self.psi_target.conj().dot(self.psi)  )**2
            reward = -np.log10( 1.0 - np.abs( self.psi_target.conj().dot(self.psi)  )**2 )
        else:
            reward = 0.0

        
        # check if state is terminal
        done=False
        
        return self.state, reward, done

    
    
    def set_seed(self,seed=0):
        """
        Sets the seed of the RNG.
        
        """
        np.random.seed(seed)
    
    
    
    def reset(self, ):
        """
        Resets the environment to its initial values.
        Returns:
            state:  object
                    the initial state of the environment
            random: bool
                    controls whether the initial state is a random state on the sphere or a fixed initial state.
        """
        self.ep_step=0 # reset step coutner
        self.CD_drive = 0.5*self.Delta * self.h_t_prime(self.dt*self.ep_step) / (self.Delta**2 + (self.h_t(self.dt*self.ep_step))**2) # -0.33
        
        self.psi=self.psi_init[:]
        self.state=self.qubit_to_RL_state(self.psi)

        return self.state

    
    
    def render(self):
        """
        Plots the state of the environment. For visulization purposes only. Feel free to ignore. 

        """
        pass
    
    
    def RL_to_qubit_state(self,s):
        """
        Take as input the RL state s, and return the quantum state |psi>
        """
        theta, phi = s
        psi = np.array([np.cos(0.5*theta), np.exp(1j*phi)*np.sin(0.5*theta)] )
        return psi
    
    
    def qubit_to_RL_state(self,psi):
        """
        Take as input the RL state s, and return the quantum state |psi>
        """
        # take away unphysical global phase
        alpha = np.angle(psi[0])
        psi_new = np.exp(-1j*alpha) * psi 
        
        # find Bloch sphere angles
        theta = 2.0*np.arccos(psi_new[0]).real
        phi = np.angle(psi_new[1])
        
        return np.array([theta, phi])

# %% [markdown]
# Let us test how the qubit environment works.

# %%
# set seed of rng (for reproducibility of the results)
n_time_steps = 40 # steps of each episode

# create environment and reset it to a random initial state
env=QubitEnv(n_time_steps,seed)
env.reset()

done=False
j=0
while j < n_time_steps:
    
    # pick a random action
    action=np.random.choice(env.actions) # equiprobable policy
    
    # take an environment step
    state=env.state.copy()
    state_p, reward, done = env.step(action)
    
    print("{}. s={}, a={}, r={}, s'={}\n".format(j, state, action, np.round(reward,6), state_p))
    
    j+=1
    
    if done:
        print('\nreached terminal state!')
        break
# Out:
# 0. s=[2.68 3.14], a=12, r=0.0, s'=[ 2.66 -3.14]
#
# 1. s=[ 2.66 -3.14], a=15, r=0.0, s'=[ 2.63 -3.14]
#
# 2. s=[ 2.63 -3.14], a=0, r=0.0, s'=[ 2.62 -3.13]
#
# 3. s=[ 2.62 -3.13], a=3, r=0.0, s'=[ 2.6  -3.13]
#
# 4. s=[ 2.6  -3.13], a=3, r=0.0, s'=[ 2.59 -3.14]
#
# 5. s=[ 2.59 -3.14], a=7, r=0.0, s'=[2.58 3.14]
#
# 6. s=[2.58 3.14], a=9, r=0.0, s'=[2.58 3.13]
#
# 7. s=[2.58 3.13], a=19, r=0.0, s'=[2.56 3.11]
#
# 8. s=[2.56 3.11], a=18, r=0.0, s'=[2.54 3.1 ]
#
# 9. s=[2.54 3.1 ], a=4, r=0.0, s'=[2.53 3.08]
#
# 10. s=[2.53 3.08], a=6, r=0.0, s'=[2.51 3.06]
#
# 11. s=[2.51 3.06], a=12, r=0.0, s'=[2.49 3.03]
#
# 12. s=[2.49 3.03], a=1, r=0.0, s'=[2.48 3.  ]
#
# 13. s=[2.48 3.  ], a=6, r=0.0, s'=[2.46 2.97]
#
# 14. s=[2.46 2.97], a=7, r=0.0, s'=[2.45 2.94]
#
# 15. s=[2.45 2.94], a=14, r=0.0, s'=[2.43 2.9 ]
#
# 16. s=[2.43 2.9 ], a=17, r=0.0, s'=[2.4  2.86]
#
# 17. s=[2.4  2.86], a=5, r=0.0, s'=[2.38 2.82]
#
# 18. s=[2.38 2.82], a=13, r=0.0, s'=[2.35 2.78]
#
# 19. s=[2.35 2.78], a=8, r=0.0, s'=[2.32 2.73]
#
# 20. s=[2.32 2.73], a=9, r=0.0, s'=[2.29 2.69]
#
# 21. s=[2.29 2.69], a=20, r=0.0, s'=[2.25 2.64]
#
# 22. s=[2.25 2.64], a=19, r=0.0, s'=[2.21 2.59]
#
# 23. s=[2.21 2.59], a=16, r=0.0, s'=[2.15 2.55]
#
# 24. s=[2.15 2.55], a=19, r=0.0, s'=[2.1 2.5]
#
# 25. s=[2.1 2.5], a=5, r=0.0, s'=[2.04 2.46]
#
# 26. s=[2.04 2.46], a=15, r=0.0, s'=[1.98 2.41]
#
# 27. s=[1.98 2.41], a=15, r=0.0, s'=[1.92 2.36]
#
# 28. s=[1.92 2.36], a=0, r=0.0, s'=[1.86 2.3 ]
#
# 29. s=[1.86 2.3 ], a=18, r=0.0, s'=[1.79 2.24]
#
# 30. s=[1.79 2.24], a=3, r=0.0, s'=[1.73 2.18]
#
# 31. s=[1.73 2.18], a=17, r=0.0, s'=[1.67 2.11]
#
# 32. s=[1.67 2.11], a=19, r=0.0, s'=[1.6  2.04]
#
# 33. s=[1.6  2.04], a=19, r=0.0, s'=[1.53 1.96]
#
# 34. s=[1.53 1.96], a=19, r=0.0, s'=[1.45 1.88]
#
# 35. s=[1.45 1.88], a=14, r=0.0, s'=[1.38 1.78]
#
# 36. s=[1.38 1.78], a=7, r=0.0, s'=[1.32 1.68]
#
# 37. s=[1.32 1.68], a=0, r=0.0, s'=[1.25 1.56]
#
# 38. s=[1.25 1.56], a=1, r=0.0, s'=[1.2  1.44]
#
# 39. s=[1.2  1.44], a=9, r=0.434482, s'=[1.14 1.31]

# %% [markdown]
# Let us now define the exact CD protocol

# %%
exact_CD_protocol = lambda t: 0.5 * env.h_t_prime(t) / (env.Delta**2 + env.h_t(t)**2)

# %% [markdown]
# Next, we find the best approximation to the exact CD protocol, within the available action space.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# reset environment
env.reset()
# preallocate arrays for approximate CD actions and the approximate CD protocol
CD_actions_t = np.zeros(env.n_time_steps, dtype=int)
CD_protocol_t = np.zeros(env.n_time_steps,)

for time_step in range(env.n_time_steps):

    # construct exact CD drive
    drive = env.h_t(env.dt*time_step)
    CD_drive = 0.5*env.Delta * env.h_t_prime(env.dt*time_step) / (env.Delta**2 + drive**2)

    # find action that gives closes value to theory CD protocol
    action = np.argmin( np.abs(env.CD_drive + env.delta_h*env.action_space - CD_drive) )
    
    # take an environment step with approximate CD action
    state[:], reward, _ = env.step(action)
    # compute instantaneous fidelity
    fidelity = np.abs( env.psi_target.conj().dot(env.psi)  )**2 

    # record approximate CD action and protocol
    CD_actions_t[time_step] = action
    CD_protocol_t[time_step]=env.CD_drive    

# store reward
reward_CD_approx = reward

# plot approximate CD protocol
times = np.arange(env.n_time_steps)*env.dt
plt.step(times, CD_protocol_t, '.-b', where='pre', label='discretized CD, $r_T={0:0.3f}$'.format(reward_CD_approx) )
plt.plot(times, exact_CD_protocol(times),'--r', label='exact CD, $r_T=\infty$' )
plt.legend()
plt.show()

# %% [markdown]
# ## Policy Gradient Implementation
#
# The implementation of the PG algorithm proceeds as follows:
#
# 1. Define the a SoftMax model for the discrete policy $\pi_\theta$.
# 2. Define the pseudo loss function to easily compute $\nabla_\theta J(\theta)$.
# 3. Define generalized gradient descent optimizer.
# 4. Define the PG training loop and train the policy.
#
# *Note:* if you are familiar with solving the MNIST problem, you will recognize many of the steps used to construct and train the neural network. What is different here is the training algorithm.
#
# ### Define a SoftMax model for the discrete policy $\pi_\theta$
#
# Use JAX to construct a feed-forward fully-connected deep neural network with neuron acrchitecture $(M_s, 512, |\mathcal{A}|)$, where there are $512$ ($256$) neurons in the first (second) hidden layer, respectively, and $M_s$ and $|\mathcal{A}|$ define the input and output sizes.
#
# The input data into the neural network should have the shape `input_shape = (-1, n_time_steps, M_s)`, where `M_s` is the number of features/components in the RL state $s=(\theta,\varphi)$. The output data should have the shape `output_shape = (-1, n_time_steps, abs_A)`, where `abs_A`$=|\mathcal{A}|$. In this way, we can use the neural network to process simultaneously all time steps and MC samples, generated in a single training iteration.
#
# Check explicitly the output shape and test that the network runs on some fake data (e.g. a small batch of vectors of ones with the appropriate shape).

# %%
import jax.numpy as jnp # jax's numpy version with GPU support
from jax import random # used to define a RNG key to control the random input in JAX
from jax.example_libraries import stax # neural network library
from jax.example_libraries.stax import Dense, Relu, LogSoftmax # neural network layers

# set key for the RNG (see JAX docs)
rng = random.PRNGKey(seed)

# define functions which initialize the parameters and evaluate the model
initialize_params, predict = stax.serial(
                                            ### fully connected DNN
                                            Dense(512), # 512 hidden neurons
                                            Relu,
                                            #Dense(256), # 256 hidden neurons
                                            #Relu,
                                            #Dense(128), # 128 hidden neurons
                                            #Relu,
                                            Dense(env.n_actions), # 4 output neurons
                                            LogSoftmax # NB: computes the log-probability
                                        )

# initialize the model parameters
input_shape = (-1,env.n_time_steps,2) # -1: number of MC points, number of time steps, size of state vector
output_shape, inital_params = initialize_params(rng, input_shape) # fcc layer 28x28 pixes in each image

print('\noutput shape of the policy network is {}.\n'.format(output_shape))


# test network
states=np.ones((3,env.n_time_steps,2), dtype=np.float32)

predictions = predict(inital_params, states)
# check the output shape
print(predictions.shape)
# Out:
# output shape of the policy network is (-1, 40, 21).
#
# (3, 40, 21)

# %% [markdown]
# ### Define the pseudo loss function to easily compute $\nabla_\theta J(\theta)$
#
# REINFORCE allows to define a scalar pseudoloss function, whose gradients give $\nabla_\theta J(\theta)$. Note that this pseudoloss does ***NOT*** correspond to the RL objective $J(\theta)$: the difference stems from the fact that the two operations of taking the derivative and performing the MC approximation are not interchangeable (do you see why?).
#
# $$
# J_\mathrm{pseudo}(\theta) =
# \frac{1}{N}\sum_{j=1}^N \sum_{t=1}^T
# \log \pi_\theta(a^j_t|s^j_t)
# \left[
# \sum_{t'=t}^T \left(r(a^j_{t'}|s^j_{t'}) - b_t \right)
# -\frac{\beta^{-1}}{2}\sum_{t'=1}^T \log \pi_\theta(a^j_{t'}|s^j_{t'})
# \right],\qquad
# b_t = \frac{1}{N}\sum_{j=1}^N G_t(\tau_j).
# $$
# The baseline is a sample average of the reward-to-go (return) from time step $t$ onwards: $G_t(\tau_j) = \sum_{t'=t}^T r(s^j_{t'},s^j_{t'})$ .
#
# Because we will be doing gradient **a**scent, do **NOT** forget to add an extra minus sign to the output ot the pseudoloss (or else your agent will end up minimizing the return).
#
# Below, we also add an L2 regularizer to the pseudoloss function to prevent overfitting.

# %%
### define loss and accuracy functions

from jax import grad
from jax.tree_util import tree_flatten # jax params are stored as nested tuples; use this to manipulate tuples


def l2_regularizer(params,lmbda=1E-3):
    """
    Define l2 regularizer: $\lambda \ sum_j ||theta_j||^2 $ for every parameter in the model $\theta_j$
    
    """
    return lmbda*jnp.sum(jnp.array([jnp.sum(jnp.abs(theta)**2) for theta in tree_flatten(params)[0] ]))

def policy_entropy_pseudo_loss(preds_select,beta_inv=1E-1):
    ent_max = env.n_time_steps*jnp.log(env.n_actions)
    return -beta_inv*0.5*jnp.sum(preds_select,axis=1)**2 / ent_max

def policy_pseudo_loss(preds_select,returns,baseline):
    #return jnp.sum(preds_select * (returns - baseline), axis=1)
    return jnp.sum(preds_select * (returns - baseline), axis=1)

def pseudo_loss(params, trajectory_batch):
    """
    Define the pseudo loss function for policy gradient. 
    
    params: object(jax pytree):
        parameters of the deep policy network.
    trajectory_batch: tuple (states, actions, returns) containing the RL states, actions and returns (not the rewards!): 
        states: np.array of size (N_MC, env.n_time_steps,2)
        actions: np.array of size (N_MC, env.n_time_steps)
        returns: np.array of size (N_MC, env.n_time_steps)
    
    Returns:
        -J_{pseudo}(\theta)

    """
    # extract data from the batch
    states, actions, returns = trajectory_batch
    # compute policy predictions
    preds = predict(params, states)
    # combute the baseline
    baseline = jnp.mean(returns, axis=0)
    # select those values of the policy along the action trajectory
    preds_select = jnp.take_along_axis(preds, jnp.expand_dims(actions, axis=2), axis=2).squeeze()
    # return negative pseudo loss function (want to maximize reward with gradient DEscent)
    return -jnp.mean(policy_pseudo_loss(preds_select,returns,baseline) + policy_entropy_pseudo_loss(preds_select)) + l2_regularizer(params)

# %% [markdown]
# ### Define generalized gradient descent optimizer
#
# Define the optimizer and the `update` function which computes the gradient o the pseudo-loss function and performs the update.
#
# We use the Adam optimizer here with `step_size = 0.001` and the rest of the parameters have default values.

# %%
### define generalized gradient descent optimizer and a function to update model parameters

from jax.example_libraries import optimizers # gradient descent optimizers
from jax import jit

step_size = 0.001 # step size or learning rate 

# compute optimizer functions
opt_init, opt_update, get_params = optimizers.adam(step_size)


# define function which updates the parameters using the change computed by the optimizer
@jit # Just In Time compilation speeds up the code; requires to use jnp everywhere; remove when debugging
def update(i, opt_state, batch):
    """
    i: int,
        counter to count how many update steps we have performed
    opt_state: object,
        the state of the optimizer
    batch: np.array
        batch containing the data used to update the model
        
    Returns: 
    opt_state: object,
        the new state of the optimizer
        
    """
    # get current parameters of the model
    current_params = get_params(opt_state)
    # compute gradients
    grad_params = grad(pseudo_loss)(current_params, batch)
    # use the optimizer to perform the update using opt_update
    return opt_update(i, grad_params, opt_state)

# %% [markdown]
# ### Define the PG training loop and train the policy
#
# Finally, we implement the REINFORCE algorithm for policy gradient.
#
# Follow the steps below:
#
# 1. Preallocate variables
#     * Define the number of episodes `N_episodes`, and the batch size `N_MC`.
#     * Preallocate arrays for the current `state`, and the `states`, `actions`, `returns` triple which defines the trajectory batch.
#     * Preallocate arrays to compute the `mean_final_reward`, `std_final_reward`, `min_final_reward`, and , `max_final_reward`.
# 2. Initialize the optimizer using the `opt_init` function.
# 3. Loop over the episodes; for every episode:
#
#     3.1 get the current Network parameters
#
#     3.2 loop to collect MC samples
#
#       3.2.1 reset the `env` and roll out the policy until the episode is over; collect the trajectory data
#
#       3.2.2 compute the returns (rewards to go)
#
#     3.3 compile the PG data into a trajectory batch
#
#     3.4 use the `update` function to update the network parameters
#
#     3.5 print instantaneous performance
#
# ***Note*** that training can take a considerably long time with the default hyperparameters.
#
# ***Note*** also that, despite fixing the seed of the random number generator, you may not be able to reproduce *precisely* the same plots from the paper since different architectures use different arithmetic instructions.

# %%
### Train model

import time

# define number of training episodes
N_episodes = 1001 #10001 # total number of training episodes
N_MC = 256 # number of trajectories in the batch


# preallocate data using arrays initialized with zeros
state=np.zeros((2,), dtype=np.float32)
    
states = np.zeros((N_MC, env.n_time_steps,2), dtype=np.float32)
actions = np.zeros((N_MC, env.n_time_steps), dtype=np.int64)
returns = np.zeros((N_MC, env.n_time_steps), dtype=np.float32)
    
# mean reward at the end of the episode
mean_final_reward = np.zeros(N_episodes, dtype=np.float32)
# standard deviation of the reward at the end of the episode
std_final_reward = np.zeros_like(mean_final_reward)
# batch minimum at the end of the episode
min_final_reward = np.zeros_like(mean_final_reward)
# batch maximum at the end of the episode
max_final_reward = np.zeros_like(mean_final_reward)
# best-seen trajectory
RL_best_seen_actions = np.zeros(env.n_time_steps, dtype=int)
max_return_ever=-100.0

print("\nStarting training...\n")

# set the initial model parameters in the optimizer
opt_state = opt_init(inital_params)

# loop over the number of training episodes
for episode in range(N_episodes): 
    
    ### record time
    start_time = time.time()
    
    # get current policy  network params
    current_params = get_params(opt_state)
    
    # MC sample
    for j in range(N_MC):
        
        # reset environment to a random initial state
        #env.reset(random=False) # fixed initial state
        env.reset() # Haar-random initial state (i.e. uniformly sampled on the sphere)
    
        # zero rewards array (auxiliary array to store the rewards, and help compute the returns)
        rewards = np.zeros((env.n_time_steps, ), dtype=np.float32)
    
        # loop over steps in an episode
        for time_step in range(env.n_time_steps):

            # select state
            state[:] = env.state[:]
            states[j,time_step,:] = state

            # select an action according to current policy
            pi_s = np.exp( predict(current_params, state) )
            #print('policy:', pi_s )
            action = np.random.choice(env.actions, p = pi_s)
            actions[j,time_step] = action

            # take an environment step
            state[:], reward, _ = env.step(action)

            # store reward
            rewards[time_step] = reward
            
            
        # compute reward-to-go 
        returns[j,:] = jnp.cumsum(rewards[::-1])[::-1]
        
        
            
    # define batch of data
    trajectory_batch = (states, actions, returns)

    # check size of losses
    preds = predict(current_params, states)
    # combute the baseline
    baseline = jnp.mean(returns, axis=0)
    # select those values of the policy along the action trajectory
    preds_select = jnp.take_along_axis(preds, jnp.expand_dims(actions, axis=2), axis=2).squeeze()
    # return negative pseudo loss function (want to maximize reward with gradient DEscent)
    print('loss comparison', -jnp.mean(policy_pseudo_loss(preds_select,returns,baseline)), -jnp.mean(policy_entropy_pseudo_loss(preds_select)),  l2_regularizer(current_params) )

    
    # update model
    opt_state = update(episode, opt_state, trajectory_batch)
            
    ### record time needed for a single epoch
    episode_time = time.time() - start_time
    
    # check performance
    mean_final_reward[episode]=jnp.mean(returns[:,-1])
    std_final_reward[episode] =jnp.std(returns[:,-1])
    min_final_reward[episode], max_final_reward[episode] = np.min(returns[:,-1]), np.max(returns[:,-1])
    ind_max = np.argmax(returns[:,-1])
    if max_final_reward[episode] > max_return_ever:
        RL_best_seen_actions[:] = actions[ind_max,:]
        max_return_ever = max_final_reward[episode]
        print("new optimal trajectory encountered:")

    
    # print results every 10 epochs
    #if episode % 5 == 0:
    print("episode {} in {:0.2f} sec".format(episode, episode_time))
    print("mean reward: {:0.6f}".format(mean_final_reward[episode]) )
    print("return standard deviation: {:0.6f}".format(std_final_reward[episode]) )
    print("min return: {:0.6f}; max return: {:0.6f}\n".format(min_final_reward[episode], max_final_reward[episode]) )
    print("max ever return: {0:0.6f}".format(max_return_ever) )
# Out:
# Starting training...
#
# loss comparison -0.048909664 6.018491 0.04403429
# new optimal trajectory encountered:
# episode 0 in 1.27 sec
# mean reward: 0.579809
# return standard deviation: 0.228208
# min return: 0.209295; max return: 1.645124
#
# max ever return: 1.645124
# loss comparison -0.058252096 6.016013 0.043821745
# episode 1 in 0.82 sec
# mean reward: 0.627053
# return standard deviation: 0.231533
# min return: 0.216591; max return: 1.452727
#
# max ever return: 1.645124
# loss comparison -0.16593206 5.9815836 0.0436091
# episode 2 in 0.82 sec
# mean reward: 0.718236
# return standard deviation: 0.249549
# min return: 0.209105; max return: 1.598472
#
# max ever return: 1.645124
# loss comparison -0.20641099 5.96558 0.04341695
# episode 3 in 0.83 sec
# mean reward: 0.725872
# return standard deviation: 0.258074
# min return: 0.249678; max return: 1.434200
#
# max ever return: 1.645124
# loss comparison -0.32750523 5.925464 0.043253094
# new optimal trajectory encountered:
# episode 4 in 0.83 sec
# mean reward: 0.800438
# return standard deviation: 0.276214
# min return: 0.212843; max return: 1.757821
#
# max ever return: 1.757821
# loss comparison -0.3083924 5.8782167 0.043110706
# episode 5 in 0.82 sec
# mean reward: 0.841656
# return standard deviation: 0.251585
# min return: 0.287879; max return: 1.509242
#
# max ever return: 1.757821
# loss comparison -0.31918108 5.8178706 0.04299066
# episode 6 in 0.81 sec
# mean reward: 0.932696
# return standard deviation: 0.249086
# min return: 0.364060; max return: 1.603134
#
# max ever return: 1.757821
# loss comparison -0.32994682 5.7821436 0.0428873
# new optimal trajectory encountered:
# episode 7 in 0.84 sec
# mean reward: 0.957748
# return standard deviation: 0.253486
# min return: 0.383767; max return: 1.770070
#
# max ever return: 1.770070
# loss comparison -0.27315968 5.7109714 0.04279906
# episode 8 in 0.80 sec
# mean reward: 1.011261
# return standard deviation: 0.232784
# min return: 0.363108; max return: 1.636091
#
# max ever return: 1.770070
# loss comparison -0.20725858 5.666793 0.04272259
# new optimal trajectory encountered:
# episode 9 in 0.81 sec
# mean reward: 1.048264
# return standard deviation: 0.228854
# min return: 0.347436; max return: 1.939743
#
# max ever return: 1.939743
# loss comparison -0.1161685 5.5927877 0.042651165
# episode 10 in 0.85 sec
# mean reward: 1.075477
# return standard deviation: 0.209659
# min return: 0.537988; max return: 1.772330
#
# max ever return: 1.939743
# loss comparison -0.14969912 5.542195 0.04258075
# episode 11 in 0.81 sec
# mean reward: 1.048947
# return standard deviation: 0.207562
# min return: 0.420599; max return: 1.707386
#
# max ever return: 1.939743
# loss comparison 0.062143683 5.456992 0.042512868
# episode 12 in 0.81 sec
# mean reward: 1.066872
# return standard deviation: 0.214815
# min return: 0.464556; max return: 1.828604
#
# max ever return: 1.939743
# loss comparison 0.14779389 5.382308 0.042436775
# episode 13 in 0.82 sec
# mean reward: 1.065795
# return standard deviation: 0.200975
# min return: 0.566047; max return: 1.807422
#
# max ever return: 1.939743
# loss comparison 0.14407545 5.37124 0.04235027
# episode 14 in 0.86 sec
# mean reward: 1.069535
# return standard deviation: 0.206086
# min return: 0.623466; max return: 1.657808
#
# max ever return: 1.939743
# loss comparison 0.18771237 5.346121 0.04225412
# episode 15 in 0.81 sec
# mean reward: 1.066576
# return standard deviation: 0.190532
# min return: 0.541667; max return: 1.577631
#
# max ever return: 1.939743
# loss comparison 0.26535937 5.285369 0.042143643
# episode 16 in 0.80 sec
# mean reward: 1.051275
# return standard deviation: 0.209971
# min return: 0.381951; max return: 1.666303
#
# max ever return: 1.939743
# loss comparison 0.34879667 5.3199024 0.042021308
# episode 17 in 0.81 sec
# mean reward: 1.077114
# return standard deviation: 0.215227
# min return: 0.433430; max return: 1.776635
#
# max ever return: 1.939743
# loss comparison 0.23824996 5.282291 0.041883368
# episode 18 in 0.79 sec
# mean reward: 1.052849
# return standard deviation: 0.194982
# min return: 0.546535; max return: 1.638242
#
# max ever return: 1.939743
# loss comparison 0.2589324 5.2589006 0.04173812
# episode 19 in 0.80 sec
# mean reward: 1.037845
# return standard deviation: 0.205689
# min return: 0.522678; max return: 1.685256
#
# max ever return: 1.939743
# loss comparison 0.25706077 5.2766438 0.041588508
# episode 20 in 0.80 sec
# mean reward: 1.077639
# return standard deviation: 0.219863
# min return: 0.502039; max return: 1.753831
#
# max ever return: 1.939743
# loss comparison 0.33284312 5.2977915 0.04143625
# episode 21 in 0.79 sec
# mean reward: 1.085108
# return standard deviation: 0.217699
# min return: 0.600100; max return: 1.788212
#
# max ever return: 1.939743
# loss comparison 0.15473244 5.2635374 0.04127779
# episode 22 in 0.80 sec
# mean reward: 1.086218
# return standard deviation: 0.203050
# min return: 0.440721; max return: 1.728825
#
# max ever return: 1.939743
# loss comparison 0.07246463 5.336027 0.04112544
# episode 23 in 0.81 sec
# mean reward: 1.100406
# return standard deviation: 0.205077
# min return: 0.580560; max return: 1.681651
#
# max ever return: 1.939743
# loss comparison 0.07472849 5.343092 0.040975526
# episode 24 in 0.86 sec
# mean reward: 1.101336
# return standard deviation: 0.231842
# min return: 0.509594; max return: 1.868905
#
# max ever return: 1.939743
# loss comparison -0.106120765 5.406323 0.04083018
# episode 25 in 0.81 sec
# mean reward: 1.122110
# return standard deviation: 0.210843
# min return: 0.573457; max return: 1.774106
#
# max ever return: 1.939743
# loss comparison 0.045004487 5.390855 0.040694244
# episode 26 in 0.82 sec
# mean reward: 1.119640
# return standard deviation: 0.216311
# min return: 0.408140; max return: 1.800235
#
# max ever return: 1.939743
# loss comparison -0.11397046 5.428791 0.04056116
# episode 27 in 0.82 sec
# mean reward: 1.113755
# return standard deviation: 0.198722
# min return: 0.514356; max return: 1.754000
#
# max ever return: 1.939743
# loss comparison -0.23521501 5.4039574 0.040437814
# episode 28 in 0.81 sec
# mean reward: 1.123483
# return standard deviation: 0.218622
# min return: 0.520677; max return: 1.763224
#
# max ever return: 1.939743
# loss comparison -0.15244365 5.4030237 0.04033133
# new optimal trajectory encountered:
# episode 29 in 0.81 sec
# mean reward: 1.129915
# return standard deviation: 0.236290
# min return: 0.514356; max return: 1.995473
#
# max ever return: 1.995473
# loss comparison -0.19862193 5.440989 0.04023401
# episode 30 in 0.81 sec
# mean reward: 1.114246
# return standard deviation: 0.232092
# min return: 0.547995; max return: 1.822866
#
# max ever return: 1.995473
# loss comparison -0.24949437 5.4174576 0.040145483
# episode 31 in 0.81 sec
# mean reward: 1.130560
# return standard deviation: 0.223074
# min return: 0.548031; max return: 1.773257
#
# max ever return: 1.995473
# loss comparison -0.32712317 5.431246 0.040067654
# new optimal trajectory encountered:
# episode 32 in 0.80 sec
# mean reward: 1.134159
# return standard deviation: 0.253542
# min return: 0.541268; max return: 2.233621
#
# max ever return: 2.233621
# loss comparison -0.3132788 5.384782 0.04000423
# episode 33 in 0.83 sec
# mean reward: 1.159462
# return standard deviation: 0.262075
# min return: 0.414601; max return: 1.852910
#
# max ever return: 2.233621
# loss comparison -0.2762531 5.3923383 0.03995367
# episode 34 in 0.82 sec
# mean reward: 1.163251
# return standard deviation: 0.249129
# min return: 0.432882; max return: 1.654377
#
# max ever return: 2.233621
# loss comparison -0.341372 5.396799 0.03991121
# episode 35 in 0.81 sec
# mean reward: 1.135403
# return standard deviation: 0.237380
# min return: 0.378966; max return: 1.827292
#
# max ever return: 2.233621
# loss comparison -0.31000212 5.3510113 0.039878942
# episode 36 in 0.80 sec
# mean reward: 1.169316
# return standard deviation: 0.261162
# min return: 0.469370; max return: 1.934759
#
# max ever return: 2.233621
# loss comparison -0.3322006 5.354074 0.039854538
# episode 37 in 0.80 sec
# mean reward: 1.154974
# return standard deviation: 0.245024
# min return: 0.559061; max return: 1.834789
#
# max ever return: 2.233621
# loss comparison -0.5355458 5.3427515 0.03983845
# new optimal trajectory encountered:
# episode 38 in 0.81 sec
# mean reward: 1.138737
# return standard deviation: 0.278611
# min return: 0.472043; max return: 2.416399
#
# max ever return: 2.416399
# loss comparison -0.30492204 5.3126984 0.03983136
# episode 39 in 0.84 sec
# mean reward: 1.166428
# return standard deviation: 0.277733
# min return: 0.505109; max return: 2.074272
#
# max ever return: 2.416399
# loss comparison -0.39040565 5.2948985 0.039830852
# episode 40 in 0.82 sec
# mean reward: 1.201045
# return standard deviation: 0.273615
# min return: 0.343944; max return: 1.848498
#
# max ever return: 2.416399
# loss comparison -0.34906197 5.2164836 0.03983723
# episode 41 in 0.81 sec
# mean reward: 1.177776
# return standard deviation: 0.258393
# min return: 0.482467; max return: 1.994457
#
# max ever return: 2.416399
# loss comparison -0.3133769 5.203067 0.039849326
# episode 42 in 0.82 sec
# mean reward: 1.195920
# return standard deviation: 0.264586
# min return: 0.434315; max return: 1.861050
#
# max ever return: 2.416399
# loss comparison -0.29898906 5.185382 0.039863788
# episode 43 in 0.81 sec
# mean reward: 1.202394
# return standard deviation: 0.272469
# min return: 0.372089; max return: 1.899965
#
# max ever return: 2.416399
# loss comparison -0.30711007 5.192907 0.039882272
# episode 44 in 0.84 sec
# mean reward: 1.179098
# return standard deviation: 0.266740
# min return: 0.512194; max return: 1.766512
#
# max ever return: 2.416399
# loss comparison -0.20303492 5.1388 0.03990544
# episode 45 in 0.81 sec
# mean reward: 1.191628
# return standard deviation: 0.270200
# min return: 0.472937; max return: 1.863285
#
# max ever return: 2.416399
# loss comparison -0.2757383 5.125907 0.03992606
# episode 46 in 0.81 sec
# mean reward: 1.204533
# return standard deviation: 0.279050
# min return: 0.560320; max return: 2.053013
#
# max ever return: 2.416399
# loss comparison -0.3794039 5.1112347 0.03995138
# episode 47 in 0.81 sec
# mean reward: 1.231580
# return standard deviation: 0.274162
# min return: 0.513424; max return: 2.107103
#
# max ever return: 2.416399
# loss comparison -0.44708756 5.1410007 0.039979372
# episode 48 in 0.84 sec
# mean reward: 1.191283
# return standard deviation: 0.272726
# min return: 0.402827; max return: 2.022984
#
# max ever return: 2.416399
# loss comparison -0.6120285 5.0740266 0.040010594
# episode 49 in 0.82 sec
# mean reward: 1.214221
# return standard deviation: 0.292236
# min return: 0.542737; max return: 1.921000
#
# max ever return: 2.416399
# loss comparison -0.28584844 5.0677147 0.040054683
# episode 50 in 0.83 sec
# mean reward: 1.217046
# return standard deviation: 0.267982
# min return: 0.430662; max return: 1.923975
#
# max ever return: 2.416399
# loss comparison -0.36503476 5.071274 0.040101647
# episode 51 in 0.80 sec
# mean reward: 1.215419
# return standard deviation: 0.279564
# min return: 0.456887; max return: 2.042982
#
# max ever return: 2.416399
# loss comparison -0.61674017 5.0180435 0.040147934
# episode 52 in 0.80 sec
# mean reward: 1.250072
# return standard deviation: 0.303303
# min return: 0.603612; max return: 2.135833
#
# max ever return: 2.416399
# loss comparison -0.28104794 4.9720535 0.040206335
# episode 53 in 0.83 sec
# mean reward: 1.232331
# return standard deviation: 0.262251
# min return: 0.495085; max return: 1.838630
#
# max ever return: 2.416399
# loss comparison -0.53316164 5.0151744 0.04026643
# episode 54 in 0.80 sec
# mean reward: 1.261331
# return standard deviation: 0.276744
# min return: 0.528583; max return: 1.905491
#
# max ever return: 2.416399
# loss comparison -0.45648098 4.9611206 0.040332306
# episode 55 in 0.80 sec
# mean reward: 1.256697
# return standard deviation: 0.277765
# min return: 0.470375; max return: 2.155173
#
# max ever return: 2.416399
# loss comparison -0.4560131 4.968878 0.04040227
# new optimal trajectory encountered:
# episode 56 in 0.84 sec
# mean reward: 1.251106
# return standard deviation: 0.317660
# min return: 0.504538; max return: 2.600139
#
# max ever return: 2.600139
# loss comparison -0.47780383 4.8072453 0.040474646
# episode 57 in 0.81 sec
# mean reward: 1.271604
# return standard deviation: 0.284589
# min return: 0.650797; max return: 2.193967
#
# max ever return: 2.600139
# loss comparison -0.58461654 4.8258657 0.04055788
# episode 58 in 0.81 sec
# mean reward: 1.257826
# return standard deviation: 0.271382
# min return: 0.478350; max return: 1.917325
#
# max ever return: 2.600139
# loss comparison -0.77656984 4.8651447 0.040644836
# episode 59 in 0.83 sec
# mean reward: 1.281022
# return standard deviation: 0.309041
# min return: 0.514778; max return: 2.203769
#
# max ever return: 2.600139
# loss comparison -0.63689446 4.735472 0.040738236
# episode 60 in 0.82 sec
# mean reward: 1.299186
# return standard deviation: 0.305694
# min return: 0.492584; max return: 2.281908
#
# max ever return: 2.600139
# loss comparison -0.65744007 4.755138 0.04084097
# episode 61 in 0.85 sec
# mean reward: 1.286364
# return standard deviation: 0.288972
# min return: 0.518953; max return: 2.214571
#
# max ever return: 2.600139
# loss comparison -0.572309 4.682515 0.0409469
# episode 62 in 0.82 sec
# mean reward: 1.303358
# return standard deviation: 0.267161
# min return: 0.384427; max return: 1.932314
#
# max ever return: 2.600139
# loss comparison -0.890236 4.744327 0.04106276
# episode 63 in 0.86 sec
# mean reward: 1.296068
# return standard deviation: 0.290104
# min return: 0.591769; max return: 2.172031
#
# max ever return: 2.600139
# loss comparison -0.5857167 4.5973186 0.041182477
# episode 64 in 0.80 sec
# mean reward: 1.360870
# return standard deviation: 0.283314
# min return: 0.700043; max return: 2.309985
#
# max ever return: 2.600139
# loss comparison -0.55001205 4.5903416 0.041311234
# episode 65 in 0.85 sec
# mean reward: 1.319332
# return standard deviation: 0.271115
# min return: 0.638417; max return: 2.092907
#
# max ever return: 2.600139
# loss comparison -0.8583727 4.500718 0.041441213
# episode 66 in 0.82 sec
# mean reward: 1.345402
# return standard deviation: 0.295326
# min return: 0.490702; max return: 2.117244
#
# max ever return: 2.600139
# loss comparison -0.44503713 4.449233 0.04158035
# episode 67 in 0.84 sec
# mean reward: 1.328165
# return standard deviation: 0.298688
# min return: 0.479017; max return: 2.305928
#
# max ever return: 2.600139
# loss comparison -0.8920882 4.4386473 0.0417189
# episode 68 in 0.81 sec
# mean reward: 1.370691
# return standard deviation: 0.293795
# min return: 0.636765; max return: 2.036576
#
# max ever return: 2.600139
# loss comparison -0.98261875 4.398991 0.04186042
# episode 69 in 0.83 sec
# mean reward: 1.355232
# return standard deviation: 0.296799
# min return: 0.529375; max return: 2.137039
#
# max ever return: 2.600139
# loss comparison -0.9002048 4.3193607 0.042005945
# episode 70 in 0.81 sec
# mean reward: 1.369264
# return standard deviation: 0.303476
# min return: 0.586390; max return: 2.350201
#
# max ever return: 2.600139
# loss comparison -0.960137 4.2497106 0.04216046
# episode 71 in 0.82 sec
# mean reward: 1.416900
# return standard deviation: 0.289174
# min return: 0.610357; max return: 2.332358
#
# max ever return: 2.600139
# loss comparison -0.8003748 4.19536 0.042322513
# episode 72 in 0.81 sec
# mean reward: 1.412068
# return standard deviation: 0.283753
# min return: 0.719639; max return: 2.298985
#
# max ever return: 2.600139
# loss comparison -1.1766688 4.111809 0.042487707
# episode 73 in 0.80 sec
# mean reward: 1.394316
# return standard deviation: 0.294864
# min return: 0.501295; max return: 2.194784
#
# max ever return: 2.600139
# loss comparison -0.9546008 4.0717697 0.04265888
# episode 74 in 0.81 sec
# mean reward: 1.402200
# return standard deviation: 0.319234
# min return: 0.626037; max return: 2.141343
#
# max ever return: 2.600139
# loss comparison -1.3252248 3.8978634 0.042831536
# episode 75 in 0.80 sec
# mean reward: 1.443907
# return standard deviation: 0.311268
# min return: 0.665583; max return: 2.440942
#
# max ever return: 2.600139
# loss comparison -0.8308277 3.8142686 0.043022595
# episode 76 in 0.80 sec
# mean reward: 1.468244
# return standard deviation: 0.306098
# min return: 0.661680; max return: 2.269432
#
# max ever return: 2.600139
# loss comparison -1.2523137 3.7967854 0.043214522
# episode 77 in 0.80 sec
# mean reward: 1.463198
# return standard deviation: 0.320034
# min return: 0.648601; max return: 2.274275
#
# max ever return: 2.600139
# loss comparison -1.4071736 3.6688094 0.043419406
# episode 78 in 0.84 sec
# mean reward: 1.484880
# return standard deviation: 0.318338
# min return: 0.651328; max return: 2.379470
#
# max ever return: 2.600139
# loss comparison -1.6025561 3.5763736 0.04362497
# episode 79 in 0.80 sec
# mean reward: 1.510475
# return standard deviation: 0.342316
# min return: 0.625991; max return: 2.440886
#
# max ever return: 2.600139
# loss comparison -0.99450076 3.4307678 0.043843087
# episode 80 in 0.81 sec
# mean reward: 1.492693
# return standard deviation: 0.329242
# min return: 0.653268; max return: 2.214502
#
# max ever return: 2.600139
# loss comparison -1.2925532 3.336678 0.04406661
# episode 81 in 0.80 sec
# mean reward: 1.503686
# return standard deviation: 0.340021
# min return: 0.564249; max return: 2.270760
#
# max ever return: 2.600139
# loss comparison -1.3378494 3.2240443 0.04428478
# episode 82 in 0.79 sec
# mean reward: 1.520676
# return standard deviation: 0.346045
# min return: 0.449361; max return: 2.342650
#
# max ever return: 2.600139
# loss comparison -1.2021617 3.0522242 0.044502877
# episode 83 in 0.80 sec
# mean reward: 1.544234
# return standard deviation: 0.342058
# min return: 0.757949; max return: 2.412869
#
# max ever return: 2.600139
# loss comparison -1.8597265 3.0863085 0.044724777
# episode 84 in 0.80 sec
# mean reward: 1.612856
# return standard deviation: 0.355907
# min return: 0.664074; max return: 2.569264
#
# max ever return: 2.600139
# loss comparison -1.7413917 2.8984947 0.044954605
# episode 85 in 0.80 sec
# mean reward: 1.605834
# return standard deviation: 0.375791
# min return: 0.675494; max return: 2.510333
#
# max ever return: 2.600139
# loss comparison -2.0008802 2.8051329 0.04520342
# episode 86 in 0.79 sec
# mean reward: 1.653571
# return standard deviation: 0.382474
# min return: 0.713956; max return: 2.541311
#
# max ever return: 2.600139
# loss comparison -1.7748911 2.6497216 0.04546263
# new optimal trajectory encountered:
# episode 87 in 0.81 sec
# mean reward: 1.622632
# return standard deviation: 0.397923
# min return: 0.587275; max return: 2.605731
#
# max ever return: 2.605731
# loss comparison -1.3838124 2.4561424 0.045737106
# new optimal trajectory encountered:
# episode 88 in 0.83 sec
# mean reward: 1.682049
# return standard deviation: 0.396232
# min return: 0.713185; max return: 2.636170
#
# max ever return: 2.636170
# loss comparison -1.7038696 2.4012547 0.04601964
# episode 89 in 0.81 sec
# mean reward: 1.689760
# return standard deviation: 0.399936
# min return: 0.748773; max return: 2.610262
#
# max ever return: 2.636170
# loss comparison -2.4940505 2.3382134 0.046307877
# episode 90 in 0.81 sec
# mean reward: 1.715675
# return standard deviation: 0.409716
# min return: 0.521226; max return: 2.624405
#
# max ever return: 2.636170
# loss comparison -2.7458935 2.2571054 0.046601433
# new optimal trajectory encountered:
# episode 91 in 0.81 sec
# mean reward: 1.721989
# return standard deviation: 0.478309
# min return: 0.677480; max return: 2.878228
#
# max ever return: 2.878228
# loss comparison -2.5845942 2.2139292 0.046898797
# episode 92 in 0.81 sec
# mean reward: 1.703440
# return standard deviation: 0.453547
# min return: 0.487680; max return: 2.866355
#
# max ever return: 2.878228
# loss comparison -2.971274 1.9626282 0.047182336
# episode 93 in 0.79 sec
# mean reward: 1.815561
# return standard deviation: 0.485775
# min return: 0.643218; max return: 2.869910
#
# max ever return: 2.878228
# loss comparison -2.3438764 1.9177142 0.047469456
# episode 94 in 0.80 sec
# mean reward: 1.764317
# return standard deviation: 0.472672
# min return: 0.695001; max return: 2.682847
#
# max ever return: 2.878228
# loss comparison -2.9614565 1.8508068 0.04776696
# new optimal trajectory encountered:
# episode 95 in 0.81 sec
# mean reward: 1.862368
# return standard deviation: 0.482061
# min return: 0.719153; max return: 2.958295
#
# max ever return: 2.958295
# loss comparison -1.5916675 1.6873806 0.048073467
# episode 96 in 0.81 sec
# mean reward: 1.773149
# return standard deviation: 0.461752
# min return: 0.672105; max return: 2.749519
#
# max ever return: 2.958295
# loss comparison -1.6296659 1.6947749 0.048389502
# episode 97 in 0.81 sec
# mean reward: 1.853951
# return standard deviation: 0.434720
# min return: 0.763649; max return: 2.753032
#
# max ever return: 2.958295
# loss comparison -1.5075828 1.4994078 0.048701856
# episode 98 in 0.84 sec
# mean reward: 1.925644
# return standard deviation: 0.430502
# min return: 0.723340; max return: 2.899357
#
# max ever return: 2.958295
# loss comparison -1.7028862 1.4830323 0.04901536
# episode 99 in 0.83 sec
# mean reward: 1.981331
# return standard deviation: 0.418203
# min return: 0.774764; max return: 2.911652
#
# max ever return: 2.958295
# loss comparison -1.6705049 1.4900045 0.04932501
# episode 100 in 0.80 sec
# mean reward: 1.955326
# return standard deviation: 0.384748
# min return: 0.770383; max return: 2.954265
#
# max ever return: 2.958295
# loss comparison -2.257903 1.3598018 0.049628463
# new optimal trajectory encountered:
# episode 101 in 0.79 sec
# mean reward: 1.986262
# return standard deviation: 0.430967
# min return: 0.737435; max return: 2.997779
#
# max ever return: 2.997779
# loss comparison -1.3072923 1.2018046 0.049932178
# episode 102 in 0.82 sec
# mean reward: 2.090206
# return standard deviation: 0.397984
# min return: 0.828039; max return: 2.995108
#
# max ever return: 2.997779
# loss comparison -1.4419838 1.1326321 0.05022966
# new optimal trajectory encountered:
# episode 103 in 0.84 sec
# mean reward: 2.036796
# return standard deviation: 0.432262
# min return: 0.764300; max return: 3.023110
#
# max ever return: 3.023110
# loss comparison -0.77581924 1.0273123 0.050537676
# new optimal trajectory encountered:
# episode 104 in 0.81 sec
# mean reward: 2.105689
# return standard deviation: 0.418004
# min return: 0.976653; max return: 3.087888
#
# max ever return: 3.087888
# loss comparison -0.9133889 0.9814216 0.05083641
# episode 105 in 0.82 sec
# mean reward: 2.098984
# return standard deviation: 0.436606
# min return: 0.800851; max return: 2.975422
#
# max ever return: 3.087888
# loss comparison -0.9587807 0.9348656 0.0511255
# episode 106 in 0.79 sec
# mean reward: 2.104352
# return standard deviation: 0.444524
# min return: 0.716635; max return: 3.084932
#
# max ever return: 3.087888
# loss comparison -1.2504992 0.85007316 0.051407196
# episode 107 in 0.80 sec
# mean reward: 2.094290
# return standard deviation: 0.466902
# min return: 0.811874; max return: 3.066848
#
# max ever return: 3.087888
# loss comparison -1.5314384 0.7941104 0.05169006
# new optimal trajectory encountered:
# episode 108 in 0.80 sec
# mean reward: 2.168248
# return standard deviation: 0.459210
# min return: 0.772025; max return: 3.273488
#
# max ever return: 3.273488
# loss comparison -1.3421078 0.7678973 0.051972184
# episode 109 in 0.80 sec
# mean reward: 2.118099
# return standard deviation: 0.466788
# min return: 0.734868; max return: 3.139387
#
# max ever return: 3.273488
# loss comparison -1.9853833 0.745052 0.052240223
# episode 110 in 0.84 sec
# mean reward: 2.160661
# return standard deviation: 0.512274
# min return: 0.704304; max return: 3.164447
#
# max ever return: 3.273488
# loss comparison -2.0043426 0.71897185 0.052500285
# episode 111 in 0.80 sec
# mean reward: 2.197427
# return standard deviation: 0.476159
# min return: 0.771043; max return: 3.141723
#
# max ever return: 3.273488
# loss comparison -1.3109199 0.6507064 0.05274404
# episode 112 in 0.80 sec
# mean reward: 2.222167
# return standard deviation: 0.491585
# min return: 0.937328; max return: 3.068568
#
# max ever return: 3.273488
# loss comparison -1.2472763 0.62795657 0.05298637
# new optimal trajectory encountered:
# episode 113 in 0.80 sec
# mean reward: 2.214225
# return standard deviation: 0.526645
# min return: 0.816781; max return: 3.273923
#
# max ever return: 3.273923
# loss comparison -1.2081889 0.6143408 0.053227894
# episode 114 in 0.81 sec
# mean reward: 2.249800
# return standard deviation: 0.478968
# min return: 0.806731; max return: 3.257712
#
# max ever return: 3.273923
# loss comparison -1.1011804 0.6226219 0.05345866
# episode 115 in 0.84 sec
# mean reward: 2.203861
# return standard deviation: 0.493642
# min return: 0.767338; max return: 3.117075
#
# max ever return: 3.273923
# loss comparison -0.71987206 0.6088489 0.053683836
# episode 116 in 0.80 sec
# mean reward: 2.288977
# return standard deviation: 0.467333
# min return: 0.985450; max return: 3.116509
#
# max ever return: 3.273923
# loss comparison -1.2467184 0.6444428 0.05389576
# episode 117 in 0.80 sec
# mean reward: 2.268423
# return standard deviation: 0.420508
# min return: 0.790128; max return: 3.173343
#
# max ever return: 3.273923
# loss comparison -1.3195329 0.66740334 0.054088537
# episode 118 in 0.81 sec
# mean reward: 2.307132
# return standard deviation: 0.431643
# min return: 0.821045; max return: 3.210885
#
# max ever return: 3.273923
# loss comparison -1.5437566 0.64199126 0.054273777
# episode 119 in 0.85 sec
# mean reward: 2.309203
# return standard deviation: 0.456779
# min return: 0.736684; max return: 3.099312
#
# max ever return: 3.273923
# loss comparison -1.7479737 0.6661428 0.054461185
# episode 120 in 0.81 sec
# mean reward: 2.233868
# return standard deviation: 0.493580
# min return: 0.725590; max return: 3.161928
#
# max ever return: 3.273923
# loss comparison -0.763665 0.59105504 0.0546492
# episode 121 in 0.80 sec
# mean reward: 2.333763
# return standard deviation: 0.503541
# min return: 0.768755; max return: 3.206245
#
# max ever return: 3.273923
# loss comparison -0.97156733 0.6278414 0.05483002
# episode 122 in 0.80 sec
# mean reward: 2.331059
# return standard deviation: 0.458166
# min return: 1.193975; max return: 3.219953
#
# max ever return: 3.273923
# loss comparison -1.2102988 0.59748685 0.05500286
# new optimal trajectory encountered:
# episode 123 in 0.80 sec
# mean reward: 2.375574
# return standard deviation: 0.487803
# min return: 0.771223; max return: 3.356315
#
# max ever return: 3.356315
# loss comparison -0.5933702 0.5890595 0.05517201
# episode 124 in 0.81 sec
# mean reward: 2.286356
# return standard deviation: 0.497036
# min return: 0.794147; max return: 3.251300
#
# max ever return: 3.356315
# loss comparison -0.9316715 0.5782538 0.055334702
# episode 125 in 0.80 sec
# mean reward: 2.379143
# return standard deviation: 0.454064
# min return: 0.766916; max return: 3.121364
#
# max ever return: 3.356315
# loss comparison -1.4442117 0.5778866 0.05549302
# episode 126 in 0.84 sec
# mean reward: 2.388488
# return standard deviation: 0.461010
# min return: 0.957464; max return: 3.188046
#
# max ever return: 3.356315
# loss comparison -1.5957472 0.57854474 0.055642925
# episode 127 in 0.83 sec
# mean reward: 2.390438
# return standard deviation: 0.488722
# min return: 0.815031; max return: 3.165323
#
# max ever return: 3.356315
# loss comparison -0.86787397 0.5357875 0.055781454
# new optimal trajectory encountered:
# episode 128 in 0.87 sec
# mean reward: 2.390378
# return standard deviation: 0.493736
# min return: 1.057984; max return: 3.356784
#
# max ever return: 3.356784
# loss comparison -0.89364094 0.5138847 0.055916045
# episode 129 in 0.81 sec
# mean reward: 2.404012
# return standard deviation: 0.477408
# min return: 1.167436; max return: 3.145764
#
# max ever return: 3.356784
# loss comparison -0.46530056 0.48953426 0.056057386
# episode 130 in 0.80 sec
# mean reward: 2.399944
# return standard deviation: 0.498143
# min return: 0.765751; max return: 3.228158
#
# max ever return: 3.356784
# loss comparison -0.9047855 0.5272019 0.05619289
# episode 131 in 0.81 sec
# mean reward: 2.360123
# return standard deviation: 0.507318
# min return: 0.738592; max return: 3.228185
#
# max ever return: 3.356784
# loss comparison -0.7216402 0.5192324 0.056326605
# episode 132 in 0.83 sec
# mean reward: 2.407851
# return standard deviation: 0.478150
# min return: 0.946581; max return: 3.223379
#
# max ever return: 3.356784
# loss comparison -0.75860465 0.5350548 0.056450885
# episode 133 in 0.80 sec
# mean reward: 2.409950
# return standard deviation: 0.472360
# min return: 0.804492; max return: 3.346938
#
# max ever return: 3.356784
# loss comparison -0.94269 0.5164665 0.056555375
# episode 134 in 0.80 sec
# mean reward: 2.423256
# return standard deviation: 0.466366
# min return: 0.932340; max return: 3.213244
#
# max ever return: 3.356784
# loss comparison -1.2255726 0.53242767 0.05664901
# episode 135 in 0.81 sec
# mean reward: 2.416780
# return standard deviation: 0.522849
# min return: 0.843263; max return: 3.236088
#
# max ever return: 3.356784
# loss comparison -0.47003937 0.48509318 0.056733888
# episode 136 in 0.79 sec
# mean reward: 2.436764
# return standard deviation: 0.511085
# min return: 0.724020; max return: 3.290725
#
# max ever return: 3.356784
# loss comparison 0.21201685 0.4777906 0.05682423
# episode 137 in 0.80 sec
# mean reward: 2.456278
# return standard deviation: 0.494126
# min return: 1.090198; max return: 3.341861
#
# max ever return: 3.356784
# loss comparison -0.50597316 0.50125283 0.056913707
# episode 138 in 0.81 sec
# mean reward: 2.408488
# return standard deviation: 0.527929
# min return: 0.901838; max return: 3.274896
#
# max ever return: 3.356784
# loss comparison -0.5273676 0.51111776 0.05700757
# episode 139 in 0.84 sec
# mean reward: 2.416910
# return standard deviation: 0.496082
# min return: 0.904148; max return: 3.286050
#
# max ever return: 3.356784
# loss comparison -0.52641654 0.5372343 0.057107016
# new optimal trajectory encountered:
# episode 140 in 0.80 sec
# mean reward: 2.477976
# return standard deviation: 0.446314
# min return: 0.987029; max return: 3.442176
#
# max ever return: 3.442176
# loss comparison -0.86164284 0.55187 0.057198696
# episode 141 in 0.81 sec
# mean reward: 2.480916
# return standard deviation: 0.456874
# min return: 0.798333; max return: 3.349139
#
# max ever return: 3.442176
# loss comparison -0.7154393 0.56443095 0.05726967
# episode 142 in 0.80 sec
# mean reward: 2.392829
# return standard deviation: 0.468901
# min return: 0.980246; max return: 3.332261
#
# max ever return: 3.442176
# loss comparison -0.8283992 0.55549675 0.057327524
# episode 143 in 0.80 sec
# mean reward: 2.435292
# return standard deviation: 0.465602
# min return: 0.763433; max return: 3.323079
#
# max ever return: 3.442176
# loss comparison -0.51352835 0.5423345 0.05737597
# new optimal trajectory encountered:
# episode 144 in 0.81 sec
# mean reward: 2.450843
# return standard deviation: 0.502166
# min return: 1.161163; max return: 3.465763
#
# max ever return: 3.465763
# loss comparison -0.029244065 0.49716157 0.05741889
# episode 145 in 0.81 sec
# mean reward: 2.422283
# return standard deviation: 0.530307
# min return: 1.038422; max return: 3.462379
#
# max ever return: 3.465763
# loss comparison -0.2026541 0.49287423 0.057471484
# episode 146 in 0.81 sec
# mean reward: 2.460802
# return standard deviation: 0.514374
# min return: 0.784453; max return: 3.315531
#
# max ever return: 3.465763
# loss comparison -0.31289303 0.50531274 0.057534665
# episode 147 in 0.80 sec
# mean reward: 2.446026
# return standard deviation: 0.494986
# min return: 1.126469; max return: 3.383383
#
# max ever return: 3.465763
# loss comparison -0.07523815 0.50902826 0.057597373
# new optimal trajectory encountered:
# episode 148 in 0.80 sec
# mean reward: 2.462341
# return standard deviation: 0.476784
# min return: 1.235707; max return: 3.715733
#
# max ever return: 3.715733
# loss comparison -0.60788065 0.5325437 0.0576469
# episode 149 in 0.83 sec
# mean reward: 2.480095
# return standard deviation: 0.500156
# min return: 1.216046; max return: 3.449009
#
# max ever return: 3.715733
# loss comparison -0.7490712 0.526351 0.05768203
# episode 150 in 0.80 sec
# mean reward: 2.487645
# return standard deviation: 0.527272
# min return: 1.182410; max return: 3.510745
#
# max ever return: 3.715733
# loss comparison -0.62765753 0.50927985 0.05771969
# episode 151 in 0.80 sec
# mean reward: 2.492645
# return standard deviation: 0.519165
# min return: 1.013663; max return: 3.500001
#
# max ever return: 3.715733
# loss comparison -0.4784189 0.4999546 0.057764728
# episode 152 in 0.81 sec
# mean reward: 2.525828
# return standard deviation: 0.519627
# min return: 1.239726; max return: 3.617075
#
# max ever return: 3.715733
# loss comparison -0.42271087 0.48150903 0.057810172
# episode 153 in 0.80 sec
# mean reward: 2.517653
# return standard deviation: 0.555031
# min return: 1.048149; max return: 3.709580
#
# max ever return: 3.715733
# loss comparison -0.3822555 0.46702683 0.05785779
# episode 154 in 0.81 sec
# mean reward: 2.534513
# return standard deviation: 0.592552
# min return: 0.838165; max return: 3.660405
#
# max ever return: 3.715733
# loss comparison -0.08142865 0.43311816 0.057911597
# new optimal trajectory encountered:
# episode 155 in 0.81 sec
# mean reward: 2.505517
# return standard deviation: 0.604669
# min return: 1.023595; max return: 3.789841
#
# max ever return: 3.789841
# loss comparison -0.7377658 0.42806566 0.05797011
# new optimal trajectory encountered:
# episode 156 in 0.80 sec
# mean reward: 2.594476
# return standard deviation: 0.591385
# min return: 1.068248; max return: 4.069512
#
# max ever return: 4.069512
# loss comparison -0.4590099 0.4064231 0.058029924
# episode 157 in 0.80 sec
# mean reward: 2.555280
# return standard deviation: 0.635224
# min return: 1.050098; max return: 3.990518
#
# max ever return: 4.069512
# loss comparison -0.3368233 0.38524824 0.058083676
# episode 158 in 0.86 sec
# mean reward: 2.566792
# return standard deviation: 0.655983
# min return: 1.017086; max return: 3.929637
#
# max ever return: 4.069512
# loss comparison -0.8342526 0.35367832 0.058131885
# new optimal trajectory encountered:
# episode 159 in 0.84 sec
# mean reward: 2.663260
# return standard deviation: 0.704211
# min return: 1.116534; max return: 4.113008
#
# max ever return: 4.113008
# loss comparison -0.6168439 0.32777897 0.058183994
# episode 160 in 0.81 sec
# mean reward: 2.669564
# return standard deviation: 0.697594
# min return: 1.234188; max return: 3.989446
#
# max ever return: 4.113008
# loss comparison -1.0851588 0.3099305 0.05823489
# new optimal trajectory encountered:
# episode 161 in 0.81 sec
# mean reward: 2.645866
# return standard deviation: 0.724031
# min return: 1.048860; max return: 4.164453
#
# max ever return: 4.164453
# loss comparison -0.983263 0.27924943 0.058289707
# new optimal trajectory encountered:
# episode 162 in 0.80 sec
# mean reward: 2.648238
# return standard deviation: 0.760922
# min return: 0.746229; max return: 4.195618
#
# max ever return: 4.195618
# loss comparison -0.88770306 0.25436032 0.058343828
# new optimal trajectory encountered:
# episode 163 in 0.80 sec
# mean reward: 2.713197
# return standard deviation: 0.750316
# min return: 1.119879; max return: 4.277272
#
# max ever return: 4.277272
# loss comparison -1.0347157 0.2437786 0.05839049
# episode 164 in 0.81 sec
# mean reward: 2.637340
# return standard deviation: 0.808117
# min return: 0.752789; max return: 4.241884
#
# max ever return: 4.277272
# loss comparison -0.93786484 0.22900127 0.058444124
# episode 165 in 0.81 sec
# mean reward: 2.640600
# return standard deviation: 0.818596
# min return: 0.940278; max return: 4.185274
#
# max ever return: 4.277272
# loss comparison -1.1094296 0.2025702 0.058501426
# episode 166 in 0.80 sec
# mean reward: 2.572678
# return standard deviation: 0.859034
# min return: 1.043383; max return: 4.147038
#
# max ever return: 4.277272
# loss comparison -1.0690923 0.21161112 0.058559824
# episode 167 in 0.82 sec
# mean reward: 2.630168
# return standard deviation: 0.805310
# min return: 1.029485; max return: 4.100960
#
# max ever return: 4.277272
# loss comparison -1.7866714 0.19647121 0.05860782
# episode 168 in 0.86 sec
# mean reward: 2.727551
# return standard deviation: 0.836219
# min return: 1.282139; max return: 4.259390
#
# max ever return: 4.277272
# loss comparison -1.5364709 0.18558282 0.0586447
# new optimal trajectory encountered:
# episode 169 in 0.81 sec
# mean reward: 2.658057
# return standard deviation: 0.895177
# min return: 1.003988; max return: 4.291421
#
# max ever return: 4.291421
# loss comparison -1.5747856 0.1730005 0.058687657
# episode 170 in 0.87 sec
# mean reward: 2.760655
# return standard deviation: 0.866525
# min return: 0.929508; max return: 4.242093
#
# max ever return: 4.291421
# loss comparison -1.3060608 0.14380462 0.058731243
# episode 171 in 0.80 sec
# mean reward: 2.672176
# return standard deviation: 0.987916
# min return: 1.001135; max return: 4.229674
#
# max ever return: 4.291421
# loss comparison -1.5421433 0.13736318 0.058768563
# new optimal trajectory encountered:
# episode 172 in 0.81 sec
# mean reward: 2.691170
# return standard deviation: 0.998349
# min return: 0.741511; max return: 4.306580
#
# max ever return: 4.306580
# loss comparison -1.8367376 0.14421791 0.05880169
# new optimal trajectory encountered:
# episode 173 in 0.81 sec
# mean reward: 2.752294
# return standard deviation: 0.928414
# min return: 1.007974; max return: 4.392916
#
# max ever return: 4.392916
# loss comparison -1.6832988 0.13663995 0.058836613
# episode 174 in 0.80 sec
# mean reward: 2.655827
# return standard deviation: 0.914299
# min return: 0.775593; max return: 4.311972
#
# max ever return: 4.392916
# loss comparison -2.3232627 0.13727924 0.0588651
# episode 175 in 0.81 sec
# mean reward: 2.706129
# return standard deviation: 0.939003
# min return: 0.701353; max return: 4.196991
#
# max ever return: 4.392916
# loss comparison -1.7361972 0.1302682 0.058895897
# episode 176 in 0.82 sec
# mean reward: 2.787634
# return standard deviation: 0.912064
# min return: 0.830244; max return: 4.336898
#
# max ever return: 4.392916
# loss comparison -1.8556542 0.12651412 0.05892404
# episode 177 in 0.81 sec
# mean reward: 2.737167
# return standard deviation: 0.951662
# min return: 0.696956; max return: 4.265182
#
# max ever return: 4.392916
# loss comparison -1.5770073 0.11989032 0.058955662
# episode 178 in 0.81 sec
# mean reward: 2.678826
# return standard deviation: 0.917965
# min return: 1.005312; max return: 4.322035
#
# max ever return: 4.392916
# loss comparison -1.5046525 0.11503388 0.058983296
# episode 179 in 0.86 sec
# mean reward: 2.680723
# return standard deviation: 0.970319
# min return: 0.998314; max return: 4.356710
#
# max ever return: 4.392916
# loss comparison -1.9800358 0.11580776 0.058999155
# episode 180 in 0.81 sec
# mean reward: 2.718758
# return standard deviation: 0.957528
# min return: 1.007853; max return: 4.340507
#
# max ever return: 4.392916
# loss comparison -1.6435196 0.11232323 0.05901493
# episode 181 in 0.81 sec
# mean reward: 2.768466
# return standard deviation: 0.938483
# min return: 0.850646; max return: 4.346130
#
# max ever return: 4.392916
# loss comparison -1.8115344 0.10374911 0.059026826
# episode 182 in 0.82 sec
# mean reward: 2.737019
# return standard deviation: 0.970937
# min return: 0.672013; max return: 4.378449
#
# max ever return: 4.392916
# loss comparison -1.7143427 0.11284594 0.059040405
# new optimal trajectory encountered:
# episode 183 in 0.81 sec
# mean reward: 2.650105
# return standard deviation: 0.947792
# min return: 0.692545; max return: 4.462203
#
# max ever return: 4.462203
# loss comparison -1.2440637 0.10510203 0.05905829
# episode 184 in 0.81 sec
# mean reward: 2.860076
# return standard deviation: 0.911728
# min return: 1.317595; max return: 4.308459
#
# max ever return: 4.462203
# loss comparison -1.607668 0.103849545 0.0590674
# episode 185 in 0.81 sec
# mean reward: 2.712370
# return standard deviation: 0.989091
# min return: 0.647255; max return: 4.351741
#
# max ever return: 4.462203
# loss comparison -2.223989 0.10495022 0.059064355
# episode 186 in 0.83 sec
# mean reward: 2.827505
# return standard deviation: 1.016539
# min return: 0.667210; max return: 4.454664
#
# max ever return: 4.462203
# loss comparison -2.2200296 0.104146525 0.05906889
# episode 187 in 0.82 sec
# mean reward: 2.746671
# return standard deviation: 1.037887
# min return: 0.726447; max return: 4.400296
#
# max ever return: 4.462203
# loss comparison -1.5931478 0.09820151 0.059075043
# episode 188 in 0.82 sec
# mean reward: 2.823602
# return standard deviation: 0.989276
# min return: 1.173946; max return: 4.322035
#
# max ever return: 4.462203
# loss comparison -1.8163018 0.09710522 0.059078734
# episode 189 in 0.82 sec
# mean reward: 2.820038
# return standard deviation: 1.012539
# min return: 0.787545; max return: 4.313758
#
# max ever return: 4.462203
# loss comparison -1.2571391 0.10033447 0.05908194
# episode 190 in 0.84 sec
# mean reward: 2.764266
# return standard deviation: 0.908265
# min return: 1.290936; max return: 4.346130
#
# max ever return: 4.462203
# loss comparison -1.5189366 0.101594366 0.059076723
# episode 191 in 0.80 sec
# mean reward: 2.717702
# return standard deviation: 0.917135
# min return: 0.501724; max return: 4.265182
#
# max ever return: 4.462203
# loss comparison -1.90325 0.10830198 0.059065867
# episode 192 in 0.81 sec
# mean reward: 2.637845
# return standard deviation: 0.922758
# min return: 1.003534; max return: 4.346130
#
# max ever return: 4.462203
# loss comparison -1.5708909 0.0940586 0.05906181
# episode 193 in 0.81 sec
# mean reward: 2.833212
# return standard deviation: 0.982312
# min return: 0.890095; max return: 4.361831
#
# max ever return: 4.462203
# loss comparison -1.6861877 0.096730955 0.059053164
# episode 194 in 0.81 sec
# mean reward: 2.636243
# return standard deviation: 1.000070
# min return: 0.971345; max return: 4.299107
#
# max ever return: 4.462203
# loss comparison -1.4270531 0.09129965 0.05904222
# episode 195 in 0.81 sec
# mean reward: 2.745770
# return standard deviation: 1.040437
# min return: 0.677781; max return: 4.360001
#
# max ever return: 4.462203
# loss comparison -1.6829901 0.0971466 0.05901853
# episode 196 in 0.82 sec
# mean reward: 2.726946
# return standard deviation: 1.016343
# min return: 0.976337; max return: 4.379084
#
# max ever return: 4.462203
# loss comparison -1.6119056 0.095979095 0.05898825
# episode 197 in 0.81 sec
# mean reward: 2.805434
# return standard deviation: 0.982768
# min return: 1.021849; max return: 4.267071
#
# max ever return: 4.462203
# loss comparison -1.5880274 0.10092615 0.058964465
# episode 198 in 0.81 sec
# mean reward: 2.704218
# return standard deviation: 0.924282
# min return: 0.678715; max return: 4.366975
#
# max ever return: 4.462203
# loss comparison -1.6382474 0.100464925 0.058940638
# episode 199 in 0.82 sec
# mean reward: 2.760146
# return standard deviation: 0.916587
# min return: 0.751480; max return: 4.319421
#
# max ever return: 4.462203
# loss comparison -1.1279912 0.09618147 0.05891892
# episode 200 in 0.85 sec
# mean reward: 2.763788
# return standard deviation: 0.916502
# min return: 0.751109; max return: 4.306290
#
# max ever return: 4.462203
# loss comparison -1.5292203 0.10315718 0.05889027
# episode 201 in 0.87 sec
# mean reward: 2.686265
# return standard deviation: 0.931545
# min return: 1.200971; max return: 4.360001
#
# max ever return: 4.462203
# loss comparison -1.574117 0.10534541 0.05886429
# episode 202 in 0.82 sec
# mean reward: 2.768078
# return standard deviation: 0.940477
# min return: 0.780204; max return: 4.379186
#
# max ever return: 4.462203
# loss comparison -1.3494989 0.09034064 0.058841895
# episode 203 in 0.85 sec
# mean reward: 2.851917
# return standard deviation: 0.979777
# min return: 1.022199; max return: 4.366555
#
# max ever return: 4.462203
# loss comparison -1.2632153 0.09428659 0.058817424
# episode 204 in 0.83 sec
# mean reward: 2.802758
# return standard deviation: 0.971713
# min return: 1.037598; max return: 4.306705
#
# max ever return: 4.462203
# loss comparison -1.7065763 0.101900056 0.05878207
# episode 205 in 0.81 sec
# mean reward: 2.886831
# return standard deviation: 0.981537
# min return: 1.026023; max return: 4.352150
#
# max ever return: 4.462203
# loss comparison -1.4554421 0.10354428 0.058754068
# episode 206 in 0.82 sec
# mean reward: 2.739251
# return standard deviation: 0.940773
# min return: 0.848510; max return: 4.329390
#
# max ever return: 4.462203
# loss comparison -1.5169629 0.10361177 0.058725566
# episode 207 in 0.81 sec
# mean reward: 2.833440
# return standard deviation: 0.872685
# min return: 1.037412; max return: 4.346007
#
# max ever return: 4.462203
# loss comparison -1.5421326 0.10595231 0.058693748
# episode 208 in 0.81 sec
# mean reward: 2.655492
# return standard deviation: 0.897605
# min return: 1.213963; max return: 4.379084
#
# max ever return: 4.462203
# loss comparison -1.6049018 0.103687815 0.05866416
# episode 209 in 0.81 sec
# mean reward: 2.734511
# return standard deviation: 0.915251
# min return: 1.025030; max return: 4.330936
#
# max ever return: 4.462203
# loss comparison -1.587666 0.098864555 0.05863954
# episode 210 in 0.85 sec
# mean reward: 2.766026
# return standard deviation: 0.993191
# min return: 0.945076; max return: 4.331817
#
# max ever return: 4.462203
# loss comparison -1.6002423 0.106670395 0.058615994
# episode 211 in 0.82 sec
# mean reward: 2.759937
# return standard deviation: 0.949856
# min return: 1.092337; max return: 4.219824
#
# max ever return: 4.462203
# loss comparison -1.5955209 0.10333964 0.058597278
# episode 212 in 0.83 sec
# mean reward: 2.759306
# return standard deviation: 0.996679
# min return: 1.029456; max return: 4.346446
#
# max ever return: 4.462203
# loss comparison -0.80109143 0.0951532 0.058577884
# episode 213 in 0.82 sec
# mean reward: 2.779193
# return standard deviation: 0.942381
# min return: 1.024149; max return: 4.408371
#
# max ever return: 4.462203
# loss comparison -1.2838559 0.09905514 0.05854723
# episode 214 in 0.82 sec
# mean reward: 2.741679
# return standard deviation: 0.901987
# min return: 1.351754; max return: 4.369908
#
# max ever return: 4.462203
# loss comparison -1.2554005 0.10239446 0.058517013
# episode 215 in 0.81 sec
# mean reward: 2.718006
# return standard deviation: 0.866159
# min return: 1.172904; max return: 4.314801
#
# max ever return: 4.462203
# loss comparison -1.5054111 0.108301036 0.058488164
# episode 216 in 0.83 sec
# mean reward: 2.795928
# return standard deviation: 0.906869
# min return: 1.289981; max return: 4.330572
#
# max ever return: 4.462203
# loss comparison -1.5448673 0.10133612 0.058459252
# episode 217 in 0.81 sec
# mean reward: 2.792117
# return standard deviation: 0.914936
# min return: 1.054002; max return: 4.337013
#
# max ever return: 4.462203
# loss comparison -1.1688163 0.096584804 0.058433395
# episode 218 in 0.82 sec
# mean reward: 2.794713
# return standard deviation: 0.962122
# min return: 1.024041; max return: 4.384100
#
# max ever return: 4.462203
# loss comparison -1.3491364 0.10203887 0.05840377
# episode 219 in 0.85 sec
# mean reward: 2.744815
# return standard deviation: 0.932209
# min return: 0.976337; max return: 4.354143
#
# max ever return: 4.462203
# loss comparison -1.7267458 0.104803175 0.05837805
# episode 220 in 0.82 sec
# mean reward: 2.825843
# return standard deviation: 0.980133
# min return: 1.033381; max return: 4.315663
#
# max ever return: 4.462203
# loss comparison -1.2723777 0.10067178 0.05836079
# episode 221 in 0.81 sec
# mean reward: 2.768745
# return standard deviation: 0.936532
# min return: 0.734726; max return: 4.304420
#
# max ever return: 4.462203
# loss comparison -1.2328211 0.09873393 0.05834891
# episode 222 in 0.81 sec
# mean reward: 2.788055
# return standard deviation: 0.911483
# min return: 1.018229; max return: 4.327558
#
# max ever return: 4.462203
# loss comparison -1.1015908 0.09741391 0.05833473
# episode 223 in 0.81 sec
# mean reward: 2.815153
# return standard deviation: 0.866220
# min return: 1.162432; max return: 4.233871
#
# max ever return: 4.462203
# loss comparison -1.6245726 0.105560854 0.05831762
# episode 224 in 0.81 sec
# mean reward: 2.819194
# return standard deviation: 0.906216
# min return: 1.035840; max return: 4.352150
#
# max ever return: 4.462203
# loss comparison -0.97966945 0.101129904 0.05830562
# episode 225 in 0.81 sec
# mean reward: 2.747364
# return standard deviation: 0.878621
# min return: 1.026334; max return: 4.346130
#
# max ever return: 4.462203
# loss comparison -1.8964865 0.10538545 0.058283437
# episode 226 in 0.85 sec
# mean reward: 2.741171
# return standard deviation: 0.913856
# min return: 1.154866; max return: 4.363540
#
# max ever return: 4.462203
# loss comparison -1.5257875 0.10439773 0.058279343
# episode 227 in 0.82 sec
# mean reward: 2.744010
# return standard deviation: 0.938346
# min return: 1.013385; max return: 4.413232
#
# max ever return: 4.462203
# loss comparison -1.6490297 0.0960726 0.05827714
# episode 228 in 0.81 sec
# mean reward: 2.910152
# return standard deviation: 0.947594
# min return: 1.030506; max return: 4.360445
#
# max ever return: 4.462203
# loss comparison -1.2194518 0.090185106 0.058279432
# episode 229 in 0.81 sec
# mean reward: 2.832741
# return standard deviation: 0.987773
# min return: 1.028131; max return: 4.321521
#
# max ever return: 4.462203
# loss comparison -1.6780405 0.10004722 0.058270942
# episode 230 in 0.81 sec
# mean reward: 2.837266
# return standard deviation: 0.978707
# min return: 1.037247; max return: 4.357351
#
# max ever return: 4.462203
# loss comparison -1.3845115 0.09448719 0.058264367
# episode 231 in 0.82 sec
# mean reward: 2.901091
# return standard deviation: 0.905486
# min return: 1.036424; max return: 4.370850
#
# max ever return: 4.462203
# loss comparison -1.3462875 0.09795815 0.05826078
# episode 232 in 0.82 sec
# mean reward: 2.778020
# return standard deviation: 0.910237
# min return: 1.056328; max return: 4.279725
#
# max ever return: 4.462203
# loss comparison -1.2328993 0.09232861 0.05825933
# episode 233 in 0.82 sec
# mean reward: 2.933647
# ...
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.09834177 0.007847525 0.14677335
# episode 9923 in 0.87 sec
# mean reward: 3.610223
# return standard deviation: 0.183047
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.11673871 0.008649223 0.14677061
# episode 9924 in 0.88 sec
# mean reward: 3.597736
# return standard deviation: 0.206754
# min return: 2.065990; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.11074954 0.007811029 0.14676608
# episode 9925 in 0.86 sec
# mean reward: 3.605314
# return standard deviation: 0.227322
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.18694434 0.008726624 0.14676133
# episode 9926 in 0.88 sec
# mean reward: 3.596337
# return standard deviation: 0.245353
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.38776225 0.009720296 0.14675738
# episode 9927 in 0.86 sec
# mean reward: 3.568976
# return standard deviation: 0.371175
# min return: 1.416770; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.18975994 0.007728531 0.14677924
# episode 9928 in 0.87 sec
# mean reward: 3.594982
# return standard deviation: 0.323970
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.13981648 0.008192456 0.14681146
# episode 9929 in 0.86 sec
# mean reward: 3.595466
# return standard deviation: 0.323111
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.20276704 0.009423748 0.14684705
# episode 9930 in 0.86 sec
# mean reward: 3.593163
# return standard deviation: 0.343732
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.22042784 0.0081154145 0.14688182
# episode 9931 in 0.86 sec
# mean reward: 3.600122
# return standard deviation: 0.300291
# min return: 2.008421; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.124872856 0.008610729 0.14692076
# episode 9932 in 0.86 sec
# mean reward: 3.599984
# return standard deviation: 0.250840
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.16540109 0.0086253425 0.14695826
# episode 9933 in 0.86 sec
# mean reward: 3.591559
# return standard deviation: 0.265633
# min return: 2.068519; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.12659337 0.007831399 0.1469872
# episode 9934 in 0.86 sec
# mean reward: 3.610064
# return standard deviation: 0.229564
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.10142365 0.0071854857 0.1470112
# episode 9935 in 0.86 sec
# mean reward: 3.618005
# return standard deviation: 0.168307
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.13198201 0.007738214 0.14703616
# episode 9936 in 0.87 sec
# mean reward: 3.622932
# return standard deviation: 0.229355
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.22057158 0.0066344696 0.1470571
# episode 9937 in 0.86 sec
# mean reward: 3.583072
# return standard deviation: 0.379192
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.2559415 0.007680751 0.14707574
# episode 9938 in 0.86 sec
# mean reward: 3.575987
# return standard deviation: 0.399139
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.26914236 0.007968321 0.14708768
# episode 9939 in 0.86 sec
# mean reward: 3.573770
# return standard deviation: 0.375364
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.12233816 0.008427308 0.147096
# episode 9940 in 0.86 sec
# mean reward: 3.590344
# return standard deviation: 0.265111
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.11690286 0.008135324 0.14710093
# episode 9941 in 0.86 sec
# mean reward: 3.585590
# return standard deviation: 0.212072
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.077820264 0.0076237884 0.14710318
# episode 9942 in 0.85 sec
# mean reward: 3.593560
# return standard deviation: 0.166293
# min return: 2.044769; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.1430102 0.008456035 0.14710334
# episode 9943 in 0.87 sec
# mean reward: 3.588316
# return standard deviation: 0.215470
# min return: 2.049345; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.117202505 0.008392729 0.14710331
# episode 9944 in 0.86 sec
# mean reward: 3.621432
# return standard deviation: 0.187781
# min return: 2.065990; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.2865158 0.007851902 0.14710256
# episode 9945 in 0.86 sec
# mean reward: 3.570057
# return standard deviation: 0.361459
# min return: 2.044769; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.2241204 0.007771901 0.14711176
# episode 9946 in 0.86 sec
# mean reward: 3.583853
# return standard deviation: 0.352017
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.34264368 0.00774364 0.14711545
# episode 9947 in 0.86 sec
# mean reward: 3.569138
# return standard deviation: 0.392017
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.21575424 0.007985663 0.14712653
# episode 9948 in 0.90 sec
# mean reward: 3.573824
# return standard deviation: 0.390849
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.18640824 0.009135154 0.1471355
# episode 9949 in 0.85 sec
# mean reward: 3.610293
# return standard deviation: 0.224043
# min return: 2.044769; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.042441856 0.008251995 0.14715587
# episode 9950 in 0.87 sec
# mean reward: 3.619263
# return standard deviation: 0.153258
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.30038208 0.008773708 0.14717133
# episode 9951 in 0.85 sec
# mean reward: 3.562566
# return standard deviation: 0.298404
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.06621303 0.008117339 0.14719391
# episode 9952 in 0.85 sec
# mean reward: 3.602734
# return standard deviation: 0.180236
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.10720915 0.008882569 0.14721085
# episode 9953 in 0.85 sec
# mean reward: 3.595201
# return standard deviation: 0.207749
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.11973035 0.008170365 0.14722274
# episode 9954 in 0.86 sec
# mean reward: 3.618778
# return standard deviation: 0.209516
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.1688569 0.008902647 0.14723264
# episode 9955 in 0.86 sec
# mean reward: 3.604740
# return standard deviation: 0.297045
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.1402004 0.008803648 0.14723578
# episode 9956 in 0.86 sec
# mean reward: 3.624655
# return standard deviation: 0.281453
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.2453471 0.007828474 0.14723396
# episode 9957 in 0.86 sec
# mean reward: 3.605579
# return standard deviation: 0.342995
# min return: 2.010963; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.29109794 0.007252855 0.14723621
# episode 9958 in 0.86 sec
# mean reward: 3.520849
# return standard deviation: 0.478348
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.18895641 0.00791147 0.14723296
# episode 9959 in 0.85 sec
# mean reward: 3.604525
# return standard deviation: 0.313782
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.17000443 0.007811228 0.14722899
# episode 9960 in 0.86 sec
# mean reward: 3.598304
# return standard deviation: 0.267171
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.1280041 0.008825463 0.14722407
# episode 9961 in 0.86 sec
# mean reward: 3.561998
# return standard deviation: 0.256646
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.14936623 0.008140856 0.14722294
# episode 9962 in 0.86 sec
# mean reward: 3.562292
# return standard deviation: 0.212979
# min return: 1.666057; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.06214149 0.00855599 0.14724198
# episode 9963 in 0.85 sec
# mean reward: 3.570073
# return standard deviation: 0.156483
# min return: 2.092667; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.12761125 0.008796912 0.14725782
# episode 9964 in 0.85 sec
# mean reward: 3.578122
# return standard deviation: 0.187276
# min return: 1.398758; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.14971144 0.009242512 0.14728217
# episode 9965 in 0.85 sec
# mean reward: 3.581443
# return standard deviation: 0.248799
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.14936525 0.007967734 0.14730443
# episode 9966 in 0.86 sec
# mean reward: 3.597934
# return standard deviation: 0.313474
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.15832269 0.008854259 0.1473224
# episode 9967 in 0.86 sec
# mean reward: 3.606792
# return standard deviation: 0.298874
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.2595307 0.008112221 0.14733888
# episode 9968 in 0.89 sec
# mean reward: 3.564708
# return standard deviation: 0.422111
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.22409196 0.007916255 0.14735128
# episode 9969 in 0.85 sec
# mean reward: 3.575414
# return standard deviation: 0.388527
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.14151436 0.008862456 0.1473562
# episode 9970 in 0.86 sec
# mean reward: 3.607716
# return standard deviation: 0.283468
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.17316763 0.0077323164 0.14736256
# episode 9971 in 0.86 sec
# mean reward: 3.602740
# return standard deviation: 0.249012
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.13619357 0.008523546 0.14736958
# episode 9972 in 0.86 sec
# mean reward: 3.595726
# return standard deviation: 0.247277
# min return: 1.426510; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.064971834 0.0074935453 0.14738168
# episode 9973 in 0.85 sec
# mean reward: 3.617588
# return standard deviation: 0.181525
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.07710522 0.008423373 0.14738935
# episode 9974 in 0.86 sec
# mean reward: 3.614774
# return standard deviation: 0.156590
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.09882092 0.00798295 0.14739306
# episode 9975 in 0.85 sec
# mean reward: 3.626017
# return standard deviation: 0.206028
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.22637543 0.008071615 0.14739579
# episode 9976 in 0.86 sec
# mean reward: 3.578758
# return standard deviation: 0.379489
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.2806763 0.009173209 0.14739814
# episode 9977 in 0.85 sec
# mean reward: 3.571450
# return standard deviation: 0.364064
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.21715948 0.007933242 0.14740026
# episode 9978 in 0.85 sec
# mean reward: 3.572126
# return standard deviation: 0.365697
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.16153952 0.0077953115 0.14739878
# episode 9979 in 0.86 sec
# mean reward: 3.612872
# return standard deviation: 0.284383
# min return: 2.008421; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.15583706 0.008304675 0.14739972
# episode 9980 in 0.85 sec
# mean reward: 3.596121
# return standard deviation: 0.227686
# min return: 2.068519; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.06940948 0.009491142 0.14739881
# episode 9981 in 0.85 sec
# mean reward: 3.615219
# return standard deviation: 0.156352
# min return: 2.095268; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.0645717 0.008029225 0.14739609
# episode 9982 in 0.85 sec
# mean reward: 3.604783
# return standard deviation: 0.181240
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.11419001 0.008544843 0.14739017
# episode 9983 in 0.86 sec
# mean reward: 3.624352
# return standard deviation: 0.247736
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.1549819 0.008544467 0.14738084
# episode 9984 in 0.86 sec
# mean reward: 3.591098
# return standard deviation: 0.311102
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.15165725 0.008382042 0.14736854
# episode 9985 in 0.85 sec
# mean reward: 3.621954
# return standard deviation: 0.277184
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.1752688 0.0082030445 0.1473631
# episode 9986 in 0.86 sec
# mean reward: 3.594680
# return standard deviation: 0.352627
# min return: 2.044769; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.14804858 0.008418329 0.14735158
# episode 9987 in 0.86 sec
# mean reward: 3.613817
# return standard deviation: 0.312050
# min return: 2.026452; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.1566814 0.00776905 0.14733796
# episode 9988 in 0.86 sec
# mean reward: 3.613169
# return standard deviation: 0.325507
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.209459 0.00890993 0.1473184
# episode 9989 in 0.85 sec
# mean reward: 3.588338
# return standard deviation: 0.313723
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.13721253 0.008724183 0.14730276
# episode 9990 in 0.86 sec
# mean reward: 3.602075
# return standard deviation: 0.201792
# min return: 2.026452; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.17741056 0.009970939 0.14729883
# episode 9991 in 0.86 sec
# mean reward: 3.555557
# return standard deviation: 0.278305
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.05297799 0.008902941 0.14729379
# episode 9992 in 0.85 sec
# mean reward: 3.581517
# return standard deviation: 0.180182
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.08263587 0.0076911785 0.14728522
# episode 9993 in 0.86 sec
# mean reward: 3.598377
# return standard deviation: 0.186278
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.16698563 0.008819474 0.14727575
# episode 9994 in 0.85 sec
# mean reward: 3.590350
# return standard deviation: 0.260180
# min return: 2.047121; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.15739787 0.008369688 0.14727387
# episode 9995 in 0.86 sec
# mean reward: 3.605240
# return standard deviation: 0.247116
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.14466266 0.007584239 0.14727587
# episode 9996 in 0.86 sec
# mean reward: 3.628567
# return standard deviation: 0.225004
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.20477614 0.008194864 0.14727631
# episode 9997 in 0.85 sec
# mean reward: 3.590573
# return standard deviation: 0.378722
# min return: 2.023941; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.22799496 0.0074731745 0.14727189
# episode 9998 in 0.86 sec
# mean reward: 3.610545
# return standard deviation: 0.326814
# min return: 2.042305; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.22493309 0.008551372 0.14726897
# episode 9999 in 0.86 sec
# mean reward: 3.599888
# return standard deviation: 0.358813
# min return: 1.860847; max return: 3.751180
#
# max ever return: 4.462203
# loss comparison -0.118065126 0.009153108 0.1472655
# episode 10000 in 0.87 sec
# mean reward: 3.604210
# return standard deviation: 0.279818
# min return: 2.063587; max return: 3.751180
#
# max ever return: 4.462203

# %% [markdown]
# ## Plot the training curves
#
# Plot the mean final reward at each episode, and its variance. What do you observe?

# %%
import matplotlib
from matplotlib import pyplot as plt

# import plotting tool
plt.rcParams.update({
    "text.usetex": True, # enable latex font
    "font.family": "Helvetica", # set font style
    "text.latex.preamble": r'\usepackage{amsmath}', # add latex packages
    "font.size": "16", # set font size
})

# static plots
# %matplotlib inline 

### plot and examine learning curves

episodes=list(range(N_episodes))

plt.plot(episodes, mean_final_reward, '-k', label='batch average' )
plt.fill_between(episodes, 
                 mean_final_reward-0.5*std_final_reward, 
                 mean_final_reward+0.5*std_final_reward, 
                 color='k', 
                 alpha=0.25)

plt.plot(episodes, min_final_reward, '.b' , markersize=1, label='batch minimum' )
plt.plot(episodes, max_final_reward, '.r' , markersize=1, label='batch maximum' )

plt.xlabel('training episode')
plt.ylabel('final reward $r_T{=}{-}\\log_{10}\\left(1{-}|\\langle\\psi_\\ast|\\psi(T)\\rangle|^2\\right) $')

plt.legend(loc='lower right')
plt.grid()
plt.show()

# np.savez('PG-STA_training',
#               episodes=episodes, 
#               mean_final_reward=mean_final_reward, 
#               std_final_reward=std_final_reward, 
#               min_final_reward=min_final_reward,
#               max_final_reward=max_final_reward,
#          )

# %%
env.reset()
RL_field_t = np.zeros(env.n_time_steps)
RL_actions_t = np.zeros(env.n_time_steps, dtype=int)
fidelity_t = np.zeros(env.n_time_steps)
fidelity_inst_t = np.zeros(env.n_time_steps)

for time_step in range(env.n_time_steps):
    #print('time step {0:d}'.format(time_step) )
    # select state
    state[:] = env.state[:]
    CD_drive=env.CD_drive
    
    # select an action according to current policy
    pi_s = np.exp( predict(current_params, state) )
    action = np.argmax(pi_s)
    #action = np.random.choice(env.actions, p = pi_s)
    #print('policy:', pi_s, np.argmax(pi_s))

    #action = RL_best_seen_actions[time_step]
    
    # record field value
    RL_field_t[time_step] = CD_drive + env.delta_h*env.action_space[action]
    RL_actions_t[time_step] = env.action_space[action]

    #print(CD_drive, env.delta_h*env.action_space[action])
    
    # take an environment step
    state[:], reward, _ = env.step(action)

    # measure target fidelity
    fidelity_t[time_step] = np.abs( env.psi_target.conj().dot(env.psi)  )**2 #reward

    # measure instantaneous fidelity
    drive = env.h_t(env.dt*env.ep_step)
    H = env.Delta*env.sigma_z + drive*env.sigma_x
    E_inst,V_inst = np.linalg.eigh(H)
    psi_inst=V_inst[:,0]

    fidelity_inst_t[time_step] = np.abs( psi_inst.conj().dot(env.psi)  )**2 #reward

reward_RL = reward

print('RL fidelity:', fidelity_t[-1])

plt.step(times, fidelity_t, '.-k', where='pre')
plt.step(times, fidelity_inst_t, '.-', color='brown', where='pre')

plt.step(times, CD_protocol_t, '.-b', where='pre', label='discretized CD, $r_T={0:0.3f}$'.format(reward_CD_approx) )
plt.step(times, RL_field_t, '.-g', where='pre', label='RL agent, $r_T={0:0.3f}$'.format(reward_RL) )
plt.plot(times, exact_CD_protocol(times),'--r', label='exact CD, $r_T=\\infty$' )

plt.legend(fontsize=14)
plt.xlabel('time $t$')

plt.show()

# np.savez('PG-STA_protocol',
#               times=times, 
#               fidelity_t=fidelity_t, 
#               fidelity_inst_t=fidelity_inst_t, 
#               RL_field_t=RL_field_t, 
#               CD_protocol_t=CD_protocol_t,
#               exact_CD_protocol=exact_CD_protocol(times),
#               reward_RL=reward_RL,
#               reward_CD_approx=reward_CD_approx,
#          )
# Out:
# RL fidelity: 0.9998190638896157

# %% [markdown]
# ## Questions
#
# **Q0.** Try out different batch sizes and hyperparameters (including different network architectures). Can you improve the performance?
#
# **Q1.** Reducing the time step size while keeping the protocol duration fixed will increase the total number of steps in an episode. Does the RL agent find the exact CD protocol in this case?
#
# **Q2.** The current problem limits the RL agent to control the $\sigma^y$ term only; add a second set of actions to also optimize the control field of the $\sigma^x$ term simultaneously. You may need to run a new hyperparameter search.
